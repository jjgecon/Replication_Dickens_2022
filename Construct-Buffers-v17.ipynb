# %% [markdown]
# # This notebook reconstructs alternative buffers to create additional data
# Ethnologue data cannot be shared freely due to copyright issues. Therefore you can only view the output of the cells.

# %% [markdown]
# # Setup

# %%
import sys, os, time
import matplotlib.pyplot as plt

# Math, data
import numpy as np
import pandas as pd
pd.set_option('display.width', 140)

# GIS packages
os.environ['USE_PYGEOS'] = '0'
from shapely.geometry import Polygon, Point
import pyproj
import georasters as gr
import fiona
import fiona.crs
import geopandas as gp
import geopandas.tools as gpt
gpd = gp
import dask_geopandas

from pyproj import CRS
cea = CRS("ESRI:54034")
wgs84 = CRS("EPSG:4326")

# Plotting
import matplotlib as mpl
import seaborn as sns
# Setup seaborn
sns.set()

# Mapping
import geoplot as gplt
import geoplot.crs as gcrs
import mapclassify as mc
import textwrap

# Various other packages
import isounidecode         # Decode and encode text
import itertools
from functools import reduce

# Paths
proot = '/work/Replication_Dickens_2022/data/'
pathout = proot + 'Ethnologue/'
pathstats = proot + 'stats/'
pathethno = '' # Since the Ethnologed is protected under copy rights we can't upload the dataset.
# Out:
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/libpysal/cg/alpha_shapes.py:39: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def nb_dist(x, y):
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/libpysal/cg/alpha_shapes.py:165: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def get_faces(triangle):
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/libpysal/cg/alpha_shapes.py:199: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def build_faces(faces, triangles_is, num_triangles, num_faces_single):
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/libpysal/cg/alpha_shapes.py:261: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def nb_mask_faces(mask, faces):

# %%
#%%px --local
def Borders(df1, df2):
    """
    Overlay Intersection operation used in overlay function
    """
    # Spatial Index to create intersections
    idx1, idx2 = df2.sindex.query_bulk(df1.geometry, predicate="intersects", sort=True)
    # Create pairs of geometries in both dataframes to be intersected
    if idx1.size > 0 and idx2.size > 0:
        left = df1.geometry.take(idx1)
        left.reset_index(drop=True, inplace=True)
        right = df2.geometry.take(idx2)
        right.reset_index(drop=True, inplace=True)
        intersections = left.intersection(right)
        poly_ix = intersections.type.isin(["LineString", "MultiLineString"])
        intersections.loc[poly_ix] = intersections[poly_ix]#.buffer(0)

        # only keep actual intersecting geometries
        pairs_intersect = pd.DataFrame({"__idx1": idx1, "__idx2": idx2})
        geom_intersect = intersections

        # merge data for intersecting geometries
        df1 = df1.reset_index(drop=True)
        df2 = df2.reset_index(drop=True)
        dfinter = pairs_intersect.merge(
            df1.drop(df1._geometry_column_name, axis=1),
            left_on="__idx1",
            right_index=True,
        )
        dfinter = dfinter.merge(
            df2.drop(df2._geometry_column_name, axis=1),
            left_on="__idx2",
            right_index=True,
            suffixes=("_1", "_2"),
        )

        return gpd.GeoDataFrame(dfinter, geometry=geom_intersect, crs=df1.crs)
    else:
        return gpd.GeoDataFrame(
            [],
            columns=list(set(df1.columns).union(df2.columns)) + ["__idx1", "__idx2"],
            crs=df1.crs,
        )
    
def _overlay_intersection(df1, df2):
    """
    Overlay Intersection operation used in overlay function
    """
    # Spatial Index to create intersections
    idx1, idx2 = df2.sindex.query_bulk(df1.geometry, predicate="intersects", sort=True)
    # Create pairs of geometries in both dataframes to be intersected
    if idx1.size > 0 and idx2.size > 0:
        left = df1.geometry.take(idx1)
        left.reset_index(drop=True, inplace=True)
        right = df2.geometry.take(idx2)
        right.reset_index(drop=True, inplace=True)
        intersections = left.intersection(right)
        poly_ix = intersections.geom_type.isin(["Polygon", "MultiPolygon"])
        intersections.loc[poly_ix] = intersections[poly_ix].buffer(0)

        # only keep actual intersecting geometries
        pairs_intersect = pd.DataFrame({"__idx1": idx1, "__idx2": idx2})
        geom_intersect = intersections

        # merge data for intersecting geometries
        df1 = df1.reset_index(drop=True)
        df2 = df2.reset_index(drop=True)
        dfinter = pairs_intersect.merge(
            df1.drop(df1._geometry_column_name, axis=1),
            left_on="__idx1",
            right_index=True,
        )
        dfinter = dfinter.merge(
            df2.drop(df2._geometry_column_name, axis=1),
            left_on="__idx2",
            right_index=True,
            suffixes=("_1", "_2"),
        )

        return gp.GeoDataFrame(dfinter, geometry=geom_intersect, crs=df1.crs)
    else:
        result = df1.iloc[:0].merge(
            df2.iloc[:0].drop(df2.geometry.name, axis=1),
            left_index=True,
            right_index=True,
            suffixes=("_1", "_2"),
        )
        result["__idx1"] = None
        result["__idx2"] = None
        return result[
            result.columns.drop(df1.geometry.name).tolist() + [df1.geometry.name]
        ]

# %%
# Drop repeated pairs
def drop_repeated(df, cols):
    df1 = df[cols].copy()
    df1['reps'] = df1.apply(lambda x: list(set(x[cols].astype(str))), axis=1)
    df1['reps'] = df1.reps.apply(lambda x: '-'.join(x))
    df1 = df1.drop_duplicates('reps')
    df1 = df1.drop('reps', axis=1).reset_index(drop=True)
    return df1

# %% [markdown]
# # Using Original Data
# ## Import original replication files provided with paper
# * We import only shapefiles to show construction and difference/similarity.
# * We import only the file for the 50km buffer (i.e., the 100km diameter)
#
# Main original replication data file with all pairwise data based on buffers of 50kms

# %%
dfor = pd.read_stata(proot + 'EJ_Dickens_Border_100km.dta')
dfor
# Out:
# /tmp/ipykernel_3341423/3197352363.py:1: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   dfor = pd.read_stata(pathdickens + 'Data/EJ_Dickens_Border_100km.dta')
#             identifier   langName_ethno1 langIso1 country1      family1    langName_ethno2 langIso2 country2       family2  lingDist  ...  \
# 0      AAA-NGA-EMA-NGA            Ghotuo      aaa  Nigeria  Niger-Congo    Emai-Iuleha-Ora      ema  Nigeria   Niger-Congo  0.459362  ...
# 1      AAA-NGA-OKE-NGA            Ghotuo      aaa  Nigeria  Niger-Congo               Okpe      oke  Nigeria   Niger-Congo  0.628569  ...
# 2      AAB-NGA-JID-NGA        Alumu-Tesu      aab  Nigeria  Niger-Congo                 Bu      jid  Nigeria   Niger-Congo  0.833333  ...
# 3      AAB-NGA-RIN-NGA        Alumu-Tesu      aab  Nigeria  Niger-Congo              Nungu      rin  Nigeria   Niger-Congo       NaN  ...
# 4      AAB-NGA-TDV-NGA        Alumu-Tesu      aab  Nigeria  Niger-Congo               Toro      tdv  Nigeria   Niger-Congo  0.532142  ...
# ...                ...               ...      ...      ...          ...                ...      ...      ...           ...       ...  ...
# 15598  ZYN-CHN-YUE-CHN   Zhuang, Yongnan      zyn    China    Tai-Kadai       Chinese, Yue      yue    China  Sino-Tibetan  0.813015  ...
# 15599  ZZJ-CHN-CMN-CHN  Zhuang, Zuojiang      zzj    China    Tai-Kadai  Chinese, Mandarin      cmn    China  Sino-Tibetan  0.865388  ...
# 15600  ZZJ-CHN-IUM-CHN  Zhuang, Zuojiang      zzj    China    Tai-Kadai            Iu Mien      ium    China    Hmong-Mien  0.844456  ...
# 15601  ZZJ-CHN-TYZ-VNM  Zhuang, Zuojiang      zzj    China    Tai-Kadai                Tay      tyz  Vietnam     Tai-Kadai  0.528902  ...
# 15602  ZZJ-CHN-ZYN-CHN  Zhuang, Zuojiang      zzj    China    Tai-Kadai    Zhuang, Yongnan      zyn    China     Tai-Kadai  0.452969  ...
#
#        langIso_ethno2  langIso_asjp1  langIso_asjp2           langName_asjp1           langName_asjp2  \
# 0                 ema            aaa            ema                   GHOTUO                     AOMA
# 1                 oke            aaa            oke                   GHOTUO                     OKPE
# 2                 jid            aab            jid                     TESU               BU_NIGERIA
# 3                 rin            aab            rin                     TESU                  missing
# 4                 tdv            aab            tdv                     TESU                     TORO
# ...               ...            ...            ...                      ...                      ...
# 15598             yue            zyn            yue  NINGMING_YONGNAN_ZHUANG                CANTONESE
# 15599             cmn            zzj            cmn          LONGZHOU_ZHUANG         KUNMING_MANDARIN
# 15600             ium            zzj            ium          LONGZHOU_ZHUANG           CHIANGRAI_MIEN
# 15601             tyz            zzj            tyz          LONGZHOU_ZHUANG                      TAY
# 15602             zyn            zzj            zyn          LONGZHOU_ZHUANG  NINGMING_YONGNAN_ZHUANG
#
#                                              familyTree1                                        familyTree2  ccode1  ccode2  region
# 0      Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...  Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...   566.0   566.0  Africa
# 1      Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...  Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...   566.0   566.0  Africa
# 2      Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...  Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...   566.0   566.0  Africa
# 3      Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...  Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...   566.0   566.0  Africa
# 4      Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...  Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...   566.0   566.0  Africa
# ...                                                  ...                                                ...     ...     ...     ...
# 15598       Tai-Kadai,Kam-Tai,Be-Tai,Tai-Sek,Tai,Central                               Sino-Tibetan,Chinese   156.0   156.0    Asia
# 15599       Tai-Kadai,Kam-Tai,Be-Tai,Tai-Sek,Tai,Central                               Sino-Tibetan,Chinese   156.0   156.0    Asia
# 15600       Tai-Kadai,Kam-Tai,Be-Tai,Tai-Sek,Tai,Central                         Hmong-Mien,Mienic,Mian-Jin   156.0   156.0    Asia
# 15601       Tai-Kadai,Kam-Tai,Be-Tai,Tai-Sek,Tai,Central       Tai-Kadai,Kam-Tai,Be-Tai,Tai-Sek,Tai,Central   156.0   704.0    Asia
# 15602       Tai-Kadai,Kam-Tai,Be-Tai,Tai-Sek,Tai,Central       Tai-Kadai,Kam-Tai,Be-Tai,Tai-Sek,Tai,Central   156.0   156.0    Asia
#
# [15603 rows x 101 columns]

# %%
dfor.loc[dfor.identifier=='SPA-MEX-SPA-GTM']
# Out:
# Empty DataFrame
# Columns: [identifier, langName_ethno1, langIso1, country1, family1, langName_ethno2, langIso2, country2, family2, lingDist, csi, csi_change, csi_sd, csi_change_sd, elev, elev_sd, elev_range, prec, prec_sd, prec_range, temp, temp_sd, temp_range, malaria, malaria_sd, malaria_range, dist_coast, dist_lake, dist_rivmaj, dist_rivmin, dist_border, dist_pre600, dist_pre1800, dist_lang, ldist_coast, ldist_lake, ldist_rivmaj, ldist_rivmin, ldist_border, ldist_lang, ldist_pre600, ldist_pre1800, asia, africa, europe, oceania, americas, oldworld, nativePop50, nativePop25, nativePop75, nativePopShare1, nativePopShare2, latitude, longitude, langLat1, langLon1, langLat2, langLon2, langLat_diff, langLon_diff, langPop1, langPop2, ln_langPop, langPop_diff, langArea1, langArea2, ln_langArea, langArea_diff, area, larea, branch1, branch2, branch3, branch4, branch5, branch6, branch7, branch8, branch9, branch10, branch11, branch12, branch13, branch14, overlap, sibling, samecountry, langID1, langID2, langIso_ethno1, langIso_ethno2, langIso_asjp1, langIso_asjp2, langName_asjp1, langName_asjp2, familyTree1, familyTree2, ccode1, ccode2, ...]
# Index: []
#
# [0 rows x 101 columns]

# %%
dfor.loc[dfor.identifier=='SPA-GTM-SPA-MEX']
# Out:
# Empty DataFrame
# Columns: [identifier, langName_ethno1, langIso1, country1, family1, langName_ethno2, langIso2, country2, family2, lingDist, csi, csi_change, csi_sd, csi_change_sd, elev, elev_sd, elev_range, prec, prec_sd, prec_range, temp, temp_sd, temp_range, malaria, malaria_sd, malaria_range, dist_coast, dist_lake, dist_rivmaj, dist_rivmin, dist_border, dist_pre600, dist_pre1800, dist_lang, ldist_coast, ldist_lake, ldist_rivmaj, ldist_rivmin, ldist_border, ldist_lang, ldist_pre600, ldist_pre1800, asia, africa, europe, oceania, americas, oldworld, nativePop50, nativePop25, nativePop75, nativePopShare1, nativePopShare2, latitude, longitude, langLat1, langLon1, langLat2, langLon2, langLat_diff, langLon_diff, langPop1, langPop2, ln_langPop, langPop_diff, langArea1, langArea2, ln_langArea, langArea_diff, area, larea, branch1, branch2, branch3, branch4, branch5, branch6, branch7, branch8, branch9, branch10, branch11, branch12, branch13, branch14, overlap, sibling, samecountry, langID1, langID2, langIso_ethno1, langIso_ethno2, langIso_asjp1, langIso_asjp2, langName_asjp1, langName_asjp2, familyTree1, familyTree2, ccode1, ccode2, ...]
# Index: []
#
# [0 rows x 101 columns]

# %%
dfor.loc[dfor.identifier=='AAA-NGA-EMA-NGA']
# Out:
#         identifier langName_ethno1 langIso1 country1      family1  langName_ethno2 langIso2 country2      family2  lingDist  ...  \
# 0  AAA-NGA-EMA-NGA          Ghotuo      aaa  Nigeria  Niger-Congo  Emai-Iuleha-Ora      ema  Nigeria  Niger-Congo  0.459362  ...
#
#    langIso_ethno2  langIso_asjp1  langIso_asjp2  langName_asjp1  langName_asjp2                                        familyTree1  \
# 0             ema            aaa            ema          GHOTUO            AOMA  Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...
#
#                                          familyTree2  ccode1  ccode2  region
# 0  Niger-Congo,Atlantic-Congo,Volta-Congo,Benue-C...   566.0   566.0  Africa
#
# [1 rows x 101 columns]

# %%
dfor.loc[dfor.identifier=='EMA-NGA-AAA-NGA']
# Out:
# Empty DataFrame
# Columns: [identifier, langName_ethno1, langIso1, country1, family1, langName_ethno2, langIso2, country2, family2, lingDist, csi, csi_change, csi_sd, csi_change_sd, elev, elev_sd, elev_range, prec, prec_sd, prec_range, temp, temp_sd, temp_range, malaria, malaria_sd, malaria_range, dist_coast, dist_lake, dist_rivmaj, dist_rivmin, dist_border, dist_pre600, dist_pre1800, dist_lang, ldist_coast, ldist_lake, ldist_rivmaj, ldist_rivmin, ldist_border, ldist_lang, ldist_pre600, ldist_pre1800, asia, africa, europe, oceania, americas, oldworld, nativePop50, nativePop25, nativePop75, nativePopShare1, nativePopShare2, latitude, longitude, langLat1, langLon1, langLat2, langLon2, langLat_diff, langLon_diff, langPop1, langPop2, ln_langPop, langPop_diff, langArea1, langArea2, ln_langArea, langArea_diff, area, larea, branch1, branch2, branch3, branch4, branch5, branch6, branch7, branch8, branch9, branch10, branch11, branch12, branch13, branch14, overlap, sibling, samecountry, langID1, langID2, langIso_ethno1, langIso_ethno2, langIso_asjp1, langIso_asjp2, langName_asjp1, langName_asjp2, familyTree1, familyTree2, ccode1, ccode2, ...]
# Index: []
#
# [0 rows x 101 columns]

# %% [markdown]
# # New Data
# ## Create borders and buffers using full dataset from Ethnologue 17 edition (paper uses version 16)
# ###  Import data

# %%
ethno = gp.read_file(pathethno + 'langa.shp')
#ethno['key'] = 0
ethno.head()
# Out:
#         ID ID_ISO_A3 ID_ISO_A2 ID_FIPS   NAM_LABEL   NAME_PROP       NAME2    NAM_ANSI       CNT                  C1        POP  \
# 0  RUS-RUS   rus-RUS    rus-ru  rus-RS     Russian     Russian     RUSSIAN     Russian    Europe  Russian Federation  137000000
# 1  ENG-USA   eng-USA    eng-us  eng-US     English     English     ENGLISH     English  Americas       United States  225000000
# 2  POR-BRA   por-BRA    por-br  por-BR  Portuguese  Portuguese  PORTUGUESE  Portuguese  Americas              Brazil  187000000
# 3  ENG-AUS   eng-AUS    eng-au  eng-AS     English     English     ENGLISH     English   Pacific           Australia   15600000
# 4  ENG-CAN   eng-CAN    eng-ca  eng-CA     English     English     ENGLISH     English  Americas              Canada   19400000
#
#       LMP_POP1                                                  G LMP_CLASS     FAMILYPROP         FAMILY              LMP_C1 LANG_ISO  \
# 0  137000000.0                        Indo-European, Slavic, East         L  Indo-European  INDO-EUROPEAN  Russian Federation      rus
# 1  225000000.0             Indo-European, Germanic, West, English         L  Indo-European  INDO-EUROPEAN       United States      eng
# 2  187000000.0  Indo-European, Italic, Romance, Italo-Western,...         L  Indo-European  INDO-EUROPEAN              Brazil      por
# 3   15600000.0             Indo-European, Germanic, West, English         L  Indo-European  INDO-EUROPEAN           Australia      eng
# 4   19400000.0             Indo-European, Germanic, West, English         L  Indo-European  INDO-EUROPEAN              Canada      eng
#
#   EGIDS                                           geometry
# 0     1  MULTIPOLYGON (((34.30387 61.85888, 34.34665 61...
# 1     1  MULTIPOLYGON (((-122.52301 47.78182, -122.5395...
# 2     1  MULTIPOLYGON (((-52.13058 -31.97901, -52.12447...
# 3     1  MULTIPOLYGON (((142.52003 -10.70436, 142.52347...
# 4     1  MULTIPOLYGON (((-74.13254 45.52187, -74.11124 ...

# %%
ethno = ethno.loc[ethno.LMP_POP1>0].reset_index(drop=True)

# %%
ethno.shape
# Out:
# (7388, 20)

# %% [markdown]
# ## Create borders and buffers using full dataset from Ethnologue 17 edition (paper uses version 16)
# Find duplicated languages x country. Unlike v16, v17 has a duplicated language

# %%
ethno.loc[ethno.duplicated('ID')]
# Out:
#            ID ID_ISO_A3 ID_ISO_A2 ID_FIPS      NAM_LABEL       NAME_PROP           NAME2        NAM_ANSI     CNT      C1      POP  \
# 4886  ALN-SRB   aln-SRB    aln-rs  aln-RI  Gheg Albanian  Albanian, Gheg  ALBANIAN, GHEG  Albanian, Gheg  Europe  Serbia  1630000
#
#        LMP_POP1                              G LMP_CLASS     FAMILYPROP         FAMILY  LMP_C1 LANG_ISO EGIDS  \
# 4886  1630000.0  Indo-European, Albanian, Gheg         L  Indo-European  INDO-EUROPEAN  Serbia      aln     2
#
#                                                geometry
# 4886  POLYGON ((21.43371 42.77874, 21.43528 42.81889...

# %%
ethno.loc[ethno['ID']=='ALN-SRB'].area
# Out:
# /tmp/ipykernel_3341423/4208167519.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   ethno.loc[ethno['ID']=='ALN-SRB'].area
# 4452    0.036987
# 4886    0.026126
# dtype: float64

# %%
ethno.loc[ethno['ID']=='ALN-SRB'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# So ALN-SRB is the only one creating duplicates.
#
# Let's create the union of these two so there is only 1 so we can replace it for the aggregate of the 2 rows.

# %%
alnsrb = ethno.loc[ethno.ID=='ALN-SRB'].reset_index(drop=True)
alnsrb
# Out:
#         ID ID_ISO_A3 ID_ISO_A2 ID_FIPS      NAM_LABEL       NAME_PROP           NAME2        NAM_ANSI     CNT      C1      POP   LMP_POP1  \
# 0  ALN-SRB   aln-SRB    aln-rs  aln-RI  Gheg Albanian  Albanian, Gheg  ALBANIAN, GHEG  Albanian, Gheg  Europe  Serbia  1630000  1630000.0
# 1  ALN-SRB   aln-SRB    aln-rs  aln-RI  Gheg Albanian  Albanian, Gheg  ALBANIAN, GHEG  Albanian, Gheg  Europe  Serbia  1630000  1630000.0
#
#                                G LMP_CLASS     FAMILYPROP         FAMILY  LMP_C1 LANG_ISO EGIDS  \
# 0  Indo-European, Albanian, Gheg         L  Indo-European  INDO-EUROPEAN  Serbia      aln     2
# 1  Indo-European, Albanian, Gheg         L  Indo-European  INDO-EUROPEAN  Serbia      aln     2
#
#                                             geometry
# 0  MULTIPOLYGON (((21.66390 42.28131, 21.65221 42...
# 1  POLYGON ((21.43371 42.77874, 21.43528 42.81889...

# %%
ethno.loc[ethno.ID=='ALN-SRB', 'geometry'] = alnsrb.dissolve(by='ID').geometry.values[0]

# %%
ethno.loc[ethno.ID=='ALN-SRB']
# Out:
#            ID ID_ISO_A3 ID_ISO_A2 ID_FIPS      NAM_LABEL       NAME_PROP           NAME2        NAM_ANSI     CNT      C1      POP  \
# 4452  ALN-SRB   aln-SRB    aln-rs  aln-RI  Gheg Albanian  Albanian, Gheg  ALBANIAN, GHEG  Albanian, Gheg  Europe  Serbia  1630000
# 4886  ALN-SRB   aln-SRB    aln-rs  aln-RI  Gheg Albanian  Albanian, Gheg  ALBANIAN, GHEG  Albanian, Gheg  Europe  Serbia  1630000
#
#        LMP_POP1                              G LMP_CLASS     FAMILYPROP         FAMILY  LMP_C1 LANG_ISO EGIDS  \
# 4452  1630000.0  Indo-European, Albanian, Gheg         L  Indo-European  INDO-EUROPEAN  Serbia      aln     2
# 4886  1630000.0  Indo-European, Albanian, Gheg         L  Indo-European  INDO-EUROPEAN  Serbia      aln     2
#
#                                                geometry
# 4452  MULTIPOLYGON (((21.65221 42.25165, 21.65133 42...
# 4886  MULTIPOLYGON (((21.65221 42.25165, 21.65133 42...

# %%
ethno = ethno.drop_duplicates(subset=['ID']).reset_index(drop=True)

# %% [markdown]
# This is an example of what Dickens calls groups that occupy non-adjacent regions of a country (fn7).
#
# No technical reasons to drop them, so we can include them.
#
# Most of these are small, so not clear this is an issue.

# %% [markdown]
# ## Create all pairs of languages/countries

# %%
import multiprocessing
nb_cpus = multiprocessing.cpu_count()

import dask.dataframe as dd
from dask.distributed import Client, progress
client = Client(processes=True,threads_per_worker=1, n_workers=nb_cpus,memory_limit='64G')

# Create a Dask client to utilize multiple cores
client = Client()
client
# Out:
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38563 instead
#   warnings.warn(
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 35271 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:40559' processes=16 threads=128, memory=500.00 GiB>

# %%
ddethno = dask_geopandas.from_geopandas(ethno, npartitions=20)
ddethno2 = dask_geopandas.from_geopandas(ethno, npartitions=20)
ddethno['geometry'] = ddethno['geometry'].buffer(0.2)
# Out:
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/dataframe/core.py:6876: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*_extract_meta(args, True), **_extract_meta(kwargs, True))

# %%
pairs = ddethno.sjoin(ddethno2, predicate="intersects").compute()
# Out:
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/distributed/client.py:3125: UserWarning: Sending large graph of size 69.37 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/dask/utils.py:73: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   return func(*args, **kwargs)

# %%
pairs.shape
# Out:
# (75972, 40)

# %%
pairs.columns = [c.replace('_left', '_1').replace('_right', '_2') for c in pairs.columns]

# %%
pairs.loc[(pairs.ID_1=='MVE-PAK')&(pairs.ID_2=='RWR-IND')]
# Out:
#         ID_1 ID_ISO_A3_1 ID_ISO_A2_1 ID_FIPS_1 NAM_LABEL_1 NAME_PROP_1  NAME2_1 NAM_ANSI_1 CNT_1      C1_1  ...   C1_2    POP_2  \
# 423  MVE-PAK     mve-PAK      mve-pk    mve-PK     Marwari     Marwari  MARWARI    Marwari  Asia  Pakistan  ...  India  5600000
#
#     LMP_POP1_2                                                G_2 LMP_CLASS_2   FAMILYPROP_2       FAMILY_2 LMP_C1_2 LANG_ISO_2 EGIDS_2
# 423  5600000.0  Indo-European, Indo-Iranian, Indo-Aryan, Centr...           L  Indo-European  INDO-EUROPEAN    India        rwr       5
#
# [1 rows x 40 columns]

# %% [raw]
# ddethno = dask_geopandas.from_geopandas(ethno, npartitions=20)
# ddethno['geometry'] = ddethno['geometry'].buffer(0.001)
# ethno02 = ddethno.compute()

# %% [raw]
# pairs = pairs.merge(ethno02[['ID', 'geometry']], how='left', left_on='ID_1', right_on='ID', suffixes=['', "_1"])
# pairs.head()

# %% [raw]
# pairs['geometry'] = pairs['geometry_1'].values
# pairs[['ID_1', 'ID', 'geometry', 'geometry_1']].head()

# %% [raw]
# pairs = pairs.drop(columns=['ID', 'geometry_1'])

# %%
pairs = pairs.merge(ethno[['ID', 'geometry']], how='left', left_on='ID_2', right_on='ID', suffixes=['_1', "_2"])
pairs[['ID_1', 'ID_2', 'ID', 'geometry_1', 'geometry_2']].head()
# Out:
#       ID_1     ID_2       ID                                         geometry_1                                         geometry_2
# 0  RUS-RUS  JPN-JPN  JPN-JPN  MULTIPOLYGON (((179.63528 65.96453, 179.62939 ...  MULTIPOLYGON (((134.24844 34.70230, 134.25470 ...
# 1  JPN-JPN  JPN-JPN  JPN-JPN  MULTIPOLYGON (((153.81556 24.15803, 153.80374 ...  MULTIPOLYGON (((134.24844 34.70230, 134.25470 ...
# 2  RUS-RUS  CMN-CHN  CMN-CHN  MULTIPOLYGON (((179.63528 65.96453, 179.62939 ...  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...
# 3  CMN-CHN  CMN-CHN  CMN-CHN  MULTIPOLYGON (((80.58287 38.16474, 80.57683 38...  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...
# 4  KHK-MNG  CMN-CHN  CMN-CHN  POLYGON ((92.34331 48.19710, 92.35761 48.20942...  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...

# %%
# %%time
pairs = pairs.loc[pairs['ID_1']!=pairs['ID_2']].reset_index(drop=True)
pairs.shape
# Out:
# CPU times: user 77.8 ms, sys: 13.3 ms, total: 91.1 ms
# Wall time: 82.5 ms
# (68585, 42)

# %%
pairs[['ID_1', 'ID_2', 'NAME2_1', 'NAME2_2']].head()
# Out:
#       ID_1     ID_2                NAME2_1            NAME2_2
# 0  RUS-RUS  JPN-JPN                RUSSIAN           JAPANESE
# 1  RUS-RUS  CMN-CHN                RUSSIAN  CHINESE, MANDARIN
# 2  KHK-MNG  CMN-CHN        MONGOLIAN, HALH  CHINESE, MANDARIN
# 3  MVF-CHN  CMN-CHN  MONGOLIAN, PERIPHERAL  CHINESE, MANDARIN
# 4  KHG-CHN  CMN-CHN         TIBETAN, KHAMS  CHINESE, MANDARIN

# %% [markdown]
# We have dropped all same pair language/countries, now let's drop all same langauge pairs that are in differenct countries (e.g., SPA-MEX and SPA-GTM). Special case MVE-PAK and RWR-IND are the same language (NAME2) even though they have different ISO codes. It's not clear there is a reason for different ISO code, so we also drop them
#
# (see https://wikitongues.org/languages/mve/, https://wikitongues.org/languages/rwr/, https://www.ethnologue.com/language/rwr/, https://www.ethnologue.com/language/mve/)
#
# **This differs from Dickens, he seems to keep these**

# %%
pairs.loc[(pairs['ID_1']=='SPA-MEX')& (pairs['ID_2']=='SPA-GTM')]
# Out:
#         ID_1 ID_ISO_A3_1 ID_ISO_A2_1 ID_FIPS_1 NAM_LABEL_1 NAME_PROP_1  NAME2_1 NAM_ANSI_1     CNT_1    C1_1  ...  LMP_POP1_2  \
# 531  SPA-MEX     spa-MEX      spa-mx    spa-MX     Spanish     Spanish  SPANISH    Spanish  Americas  Mexico  ...   9000000.0
#
#                                                    G_2 LMP_CLASS_2   FAMILYPROP_2       FAMILY_2   LMP_C1_2 LANG_ISO_2 EGIDS_2       ID  \
# 531  Indo-European, Italic, Romance, Italo-Western,...           L  Indo-European  INDO-EUROPEAN  Guatemala        spa       1  SPA-GTM
#
#                                             geometry_2
# 531  MULTIPOLYGON (((-88.49902 15.89139, -88.44183 ...
#
# [1 rows x 42 columns]

# %%
pairs = pairs.loc[pairs['NAME2_1']!=pairs['NAME2_2']].reset_index(drop=True)
#pairs = pairs.loc[(pairs['ID_1']!='ALN-SRB') & (pairs['ID_2']!='ALN-SRB')].reset_index(drop=True)
pairs.shape
# Out:
# (67221, 42)

# %%
# %%time
non_repeated_pairs = drop_repeated(pairs, ['ID_1', 'ID_2'])
# Out:
# CPU times: user 20 s, sys: 219 ms, total: 20.2 s
# Wall time: 19.7 s

# %%
non_repeated_pairs
# Out:
#           ID_1     ID_2
# 0      RUS-RUS  JPN-JPN
# 1      RUS-RUS  CMN-CHN
# 2      KHK-MNG  CMN-CHN
# 3      MVF-CHN  CMN-CHN
# 4      KHG-CHN  CMN-CHN
# ...        ...      ...
# 36669  DJE-BFA  HAU-BFA
# 36670  HAU-BFA  DJE-BFA
# 36671  AFN-NGA  NKX-NGA
# 36672  BHE-PAK  AEQ-PAK
# 36673  XNB-TWN  SXR-TWN
#
# [36674 rows x 2 columns]

# %%
a = pairs.loc[(pairs['ID_1']=='SPA-CHL') & (pairs['ID_2']=='ARN-ARG')].reset_index()
#a = pairs.loc[(pairs['ID_1']=='KHK-MNG') & (pairs['ID_2']=='CMN-CHN')].reset_index()
a.apply(lambda x: x.geometry_1.intersection(x.geometry_2.boundary), axis=1)
# Out:
# 0    MULTILINESTRING ((-71.5553790344726 -43.093965...
# dtype: object

# %%
ddpairs = dask_geopandas.from_geopandas(pairs, npartitions=100)

# %%
# %%time
ddpairs['border'] = ddpairs.apply(lambda x: x.geometry_1.intersection(x.geometry_2.boundary), axis=1, meta=(None, 'geometry'))
#borders = ddpairs.compute(scheduler="threads", num_workers=120)
borders = ddpairs.compute()
# Out:
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/distributed/client.py:3125: UserWarning: Sending large graph of size 1.65 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# CPU times: user 30.5 s, sys: 7.57 s, total: 38 s
# Wall time: 36.7 s

# %%
borders[['ID_1', 'ID_2', 'geometry_1', 'geometry_2', 'border']]
# Out:
#           ID_1     ID_2                                         geometry_1                                         geometry_2  \
# 0      RUS-RUS  JPN-JPN  MULTIPOLYGON (((179.63528 65.96453, 179.62939 ...  MULTIPOLYGON (((134.24844 34.70230, 134.25470 ...
# 1      RUS-RUS  CMN-CHN  MULTIPOLYGON (((179.63528 65.96453, 179.62939 ...  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...
# 2      KHK-MNG  CMN-CHN  POLYGON ((92.34331 48.19710, 92.35761 48.20942...  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...
# 3      MVF-CHN  CMN-CHN  POLYGON ((97.30358 41.93900, 97.29472 41.94927...  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...
# 4      KHG-CHN  CMN-CHN  POLYGON ((86.24880 31.02358, 86.25015 31.02981...  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...
# ...        ...      ...                                                ...                                                ...
# 67216  NKX-NGA  AFN-NGA  POLYGON ((7.61630 4.67900, 7.62824 4.66421, 7....  POLYGON ((7.46418 4.54514, 7.46363 4.54509, 7....
# 67217  BHE-PAK  AEQ-PAK  POLYGON ((69.46580 25.47820, 69.46580 25.47827...  POLYGON ((69.54476 25.17083, 69.54605 25.17116...
# 67218  AEQ-PAK  BHE-PAK  POLYGON ((69.40962 25.31827, 69.42491 25.33095...  POLYGON ((69.48241 25.27896, 69.48404 25.27909...
# 67219  XNB-TWN  SXR-TWN  POLYGON ((120.87169 23.52521, 120.88809 23.525...  POLYGON ((120.71130 23.26549, 120.71258 23.264...
# 67220  SXR-TWN  XNB-TWN  POLYGON ((120.75052 23.46160, 120.76875 23.457...  POLYGON ((120.88788 23.32587, 120.88789 23.325...
#
#                                                   border
# 0      MULTILINESTRING ((145.26184708531085 43.613034...
# 1      MULTILINESTRING ((124.36592265983182 53.027715...
# 2      LINESTRING (96.29691477755095 42.5289806328061...
# 3      MULTILINESTRING ((115.35494924338084 41.864068...
# 4      LINESTRING (102.2426301910543 29.7254765507846...
# ...                                                  ...
# 67216  LINESTRING (7.4641768907509345 4.5451402848962...
# 67217  LINESTRING (69.5447627149274 25.17083470465792...
# 67218  LINESTRING (69.48240614882474 25.2789589298108...
# 67219  LINESTRING (120.711301000341 23.26548799967150...
# 67220  LINESTRING (120.88788200005433 23.325865999716...
#
# [67221 rows x 5 columns]

# %%
borders.loc[0, 'border']
# Out:
# <MULTILINESTRING ((145.262 43.613, 145.289 43.608, 145.315 43.6, 145.339 43....>

# %%
borders_geo = gp.GeoDataFrame(borders, crs=ethno.crs, geometry='border')
borders_geo.head()
# Out:
#       ID_1 ID_ISO_A3_1 ID_ISO_A2_1 ID_FIPS_1           NAM_LABEL_1            NAME_PROP_1                NAME2_1             NAM_ANSI_1  \
# 0  RUS-RUS     rus-RUS      rus-ru    rus-RS               Russian                Russian                RUSSIAN                Russian
# 1  RUS-RUS     rus-RUS      rus-ru    rus-RS               Russian                Russian                RUSSIAN                Russian
# 2  KHK-MNG     khk-MNG      khk-mn    khk-MG        Halh Mongolian        Mongolian, Halh        MONGOLIAN, HALH        Mongolian, Halh
# 3  MVF-CHN     mvf-CHN      mvf-cn    mvf-CH  Peripheral Mongolian  Mongolian, Peripheral  MONGOLIAN, PERIPHERAL  Mongolian, Peripheral
# 4  KHG-CHN     khg-CHN      khg-cn    khg-CH         Khams Tibetan         Tibetan, Khams         TIBETAN, KHAMS         Tibetan, Khams
#
#     CNT_1                C1_1  ...                    G_2  LMP_CLASS_2  FAMILYPROP_2      FAMILY_2 LMP_C1_2 LANG_ISO_2 EGIDS_2       ID  \
# 0  Europe  Russian Federation  ...                Japonic            L       Japonic       JAPONIC    Japan        jpn       1  JPN-JPN
# 1  Europe  Russian Federation  ...  Sino-Tibetan, Chinese            L  Sino-Tibetan  SINO-TIBETAN    China        cmn       1  CMN-CHN
# 2    Asia            Mongolia  ...  Sino-Tibetan, Chinese            L  Sino-Tibetan  SINO-TIBETAN    China        cmn       1  CMN-CHN
# 3    Asia               China  ...  Sino-Tibetan, Chinese            L  Sino-Tibetan  SINO-TIBETAN    China        cmn       1  CMN-CHN
# 4    Asia               China  ...  Sino-Tibetan, Chinese            L  Sino-Tibetan  SINO-TIBETAN    China        cmn       1  CMN-CHN
#
#                                           geometry_2                                             border
# 0  MULTIPOLYGON (((134.24844 34.70230, 134.25470 ...  MULTILINESTRING ((145.26185 43.61303, 145.2890...
# 1  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...  MULTILINESTRING ((124.36592 53.02772, 124.3888...
# 2  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...  LINESTRING (96.29691 42.52898, 96.30858 42.544...
# 3  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...  MULTILINESTRING ((115.35495 41.86407, 115.3246...
# 4  MULTIPOLYGON (((116.32026 40.72407, 116.42109 ...  LINESTRING (102.24263 29.72548, 102.20450 29.7...
#
# [5 rows x 43 columns]

# %%
borders_geo[borders_geo.columns.difference(['geometry_1', 'geometry_2'])].to_file(pathout + 'ethnologue_bordersv17.json', driver="GeoJSON")
#borders_geo.to_csv(pathout + 'ethnologue_bordersv16.csv', encoding='utf8', index=False)

# %% [markdown]
# ## Overlap Datasets
#
# Let's see overlap between both datasets and ways to merge
#
# Create alternative IDs since we do not know order

# %%
borders_geo['identifier'] = borders_geo['ID_1'] + '-' + borders_geo['ID_2']
borders_geo['identifier']
# Out:
# 0        RUS-RUS-JPN-JPN
# 1        RUS-RUS-CMN-CHN
# 2        KHK-MNG-CMN-CHN
# 3        MVF-CHN-CMN-CHN
# 4        KHG-CHN-CMN-CHN
#               ...
# 67216    NKX-NGA-AFN-NGA
# 67217    BHE-PAK-AEQ-PAK
# 67218    AEQ-PAK-BHE-PAK
# 67219    XNB-TWN-SXR-TWN
# 67220    SXR-TWN-XNB-TWN
# Name: identifier, Length: 67221, dtype: object

# %%
dfor['ID_1'] = dfor['identifier'].apply(lambda x: x[:7])
dfor['ID_2'] = dfor['identifier'].apply(lambda x: x[8:])
dfor['ID_1alt'] = dfor['ID_2']
dfor['ID_2alt'] = dfor['ID_1']
dfor[['ID_1', 'ID_2', 'ID_1alt', 'ID_2alt', 'identifier']]
# Out:
#           ID_1     ID_2  ID_1alt  ID_2alt       identifier
# 0      AAA-NGA  EMA-NGA  EMA-NGA  AAA-NGA  AAA-NGA-EMA-NGA
# 1      AAA-NGA  OKE-NGA  OKE-NGA  AAA-NGA  AAA-NGA-OKE-NGA
# 2      AAB-NGA  JID-NGA  JID-NGA  AAB-NGA  AAB-NGA-JID-NGA
# 3      AAB-NGA  RIN-NGA  RIN-NGA  AAB-NGA  AAB-NGA-RIN-NGA
# 4      AAB-NGA  TDV-NGA  TDV-NGA  AAB-NGA  AAB-NGA-TDV-NGA
# ...        ...      ...      ...      ...              ...
# 15598  ZYN-CHN  YUE-CHN  YUE-CHN  ZYN-CHN  ZYN-CHN-YUE-CHN
# 15599  ZZJ-CHN  CMN-CHN  CMN-CHN  ZZJ-CHN  ZZJ-CHN-CMN-CHN
# 15600  ZZJ-CHN  IUM-CHN  IUM-CHN  ZZJ-CHN  ZZJ-CHN-IUM-CHN
# 15601  ZZJ-CHN  TYZ-VNM  TYZ-VNM  ZZJ-CHN  ZZJ-CHN-TYZ-VNM
# 15602  ZZJ-CHN  ZYN-CHN  ZYN-CHN  ZZJ-CHN  ZZJ-CHN-ZYN-CHN
#
# [15603 rows x 5 columns]

# %% [markdown]
# We check for non-repeated language-country pairs in original data

# %%
dfor.loc[dfor.duplicated('identifier')]
# Out:
# Empty DataFrame
# Columns: [identifier, langName_ethno1, langIso1, country1, family1, langName_ethno2, langIso2, country2, family2, lingDist, csi, csi_change, csi_sd, csi_change_sd, elev, elev_sd, elev_range, prec, prec_sd, prec_range, temp, temp_sd, temp_range, malaria, malaria_sd, malaria_range, dist_coast, dist_lake, dist_rivmaj, dist_rivmin, dist_border, dist_pre600, dist_pre1800, dist_lang, ldist_coast, ldist_lake, ldist_rivmaj, ldist_rivmin, ldist_border, ldist_lang, ldist_pre600, ldist_pre1800, asia, africa, europe, oceania, americas, oldworld, nativePop50, nativePop25, nativePop75, nativePopShare1, nativePopShare2, latitude, longitude, langLat1, langLon1, langLat2, langLon2, langLat_diff, langLon_diff, langPop1, langPop2, ln_langPop, langPop_diff, langArea1, langArea2, ln_langArea, langArea_diff, area, larea, branch1, branch2, branch3, branch4, branch5, branch6, branch7, branch8, branch9, branch10, branch11, branch12, branch13, branch14, overlap, sibling, samecountry, langID1, langID2, langIso_ethno1, langIso_ethno2, langIso_asjp1, langIso_asjp2, langName_asjp1, langName_asjp2, familyTree1, familyTree2, ccode1, ccode2, ...]
# Index: []
#
# [0 rows x 105 columns]

# %%
dfor.loc[dfor.duplicated(subset=['ID_1', 'ID_2'])]
# Out:
# Empty DataFrame
# Columns: [identifier, langName_ethno1, langIso1, country1, family1, langName_ethno2, langIso2, country2, family2, lingDist, csi, csi_change, csi_sd, csi_change_sd, elev, elev_sd, elev_range, prec, prec_sd, prec_range, temp, temp_sd, temp_range, malaria, malaria_sd, malaria_range, dist_coast, dist_lake, dist_rivmaj, dist_rivmin, dist_border, dist_pre600, dist_pre1800, dist_lang, ldist_coast, ldist_lake, ldist_rivmaj, ldist_rivmin, ldist_border, ldist_lang, ldist_pre600, ldist_pre1800, asia, africa, europe, oceania, americas, oldworld, nativePop50, nativePop25, nativePop75, nativePopShare1, nativePopShare2, latitude, longitude, langLat1, langLon1, langLat2, langLon2, langLat_diff, langLon_diff, langPop1, langPop2, ln_langPop, langPop_diff, langArea1, langArea2, ln_langArea, langArea_diff, area, larea, branch1, branch2, branch3, branch4, branch5, branch6, branch7, branch8, branch9, branch10, branch11, branch12, branch13, branch14, overlap, sibling, samecountry, langID1, langID2, langIso_ethno1, langIso_ethno2, langIso_asjp1, langIso_asjp2, langName_asjp1, langName_asjp2, familyTree1, familyTree2, ccode1, ccode2, ...]
# Index: []
#
# [0 rows x 105 columns]

# %%
dfor.loc[dfor.duplicated(subset=['ID_1', 'ID_2'])]
# Out:
# Empty DataFrame
# Columns: [identifier, langName_ethno1, langIso1, country1, family1, langName_ethno2, langIso2, country2, family2, lingDist, csi, csi_change, csi_sd, csi_change_sd, elev, elev_sd, elev_range, prec, prec_sd, prec_range, temp, temp_sd, temp_range, malaria, malaria_sd, malaria_range, dist_coast, dist_lake, dist_rivmaj, dist_rivmin, dist_border, dist_pre600, dist_pre1800, dist_lang, ldist_coast, ldist_lake, ldist_rivmaj, ldist_rivmin, ldist_border, ldist_lang, ldist_pre600, ldist_pre1800, asia, africa, europe, oceania, americas, oldworld, nativePop50, nativePop25, nativePop75, nativePopShare1, nativePopShare2, latitude, longitude, langLat1, langLon1, langLat2, langLon2, langLat_diff, langLon_diff, langPop1, langPop2, ln_langPop, langPop_diff, langArea1, langArea2, ln_langArea, langArea_diff, area, larea, branch1, branch2, branch3, branch4, branch5, branch6, branch7, branch8, branch9, branch10, branch11, branch12, branch13, branch14, overlap, sibling, samecountry, langID1, langID2, langIso_ethno1, langIso_ethno2, langIso_asjp1, langIso_asjp2, langName_asjp1, langName_asjp2, familyTree1, familyTree2, ccode1, ccode2, ...]
# Index: []
#
# [0 rows x 105 columns]

# %% [markdown]
# ## Merge

# %%
merge_iden = dfor[['identifier']].merge(borders_geo[['ID_1', 'ID_2', 'identifier']])
merge_iden
# Out:
#             identifier     ID_1     ID_2
# 0      AAA-NGA-EMA-NGA  AAA-NGA  EMA-NGA
# 1      AAB-NGA-JID-NGA  AAB-NGA  JID-NGA
# 2      AAB-NGA-RIN-NGA  AAB-NGA  RIN-NGA
# 3      AAB-NGA-TDV-NGA  AAB-NGA  TDV-NGA
# 4      AAC-PNG-DBY-PNG  AAC-PNG  DBY-PNG
# ...                ...      ...      ...
# 13820  ZYN-CHN-YUE-CHN  ZYN-CHN  YUE-CHN
# 13821  ZZJ-CHN-CMN-CHN  ZZJ-CHN  CMN-CHN
# 13822  ZZJ-CHN-IUM-CHN  ZZJ-CHN  IUM-CHN
# 13823  ZZJ-CHN-TYZ-VNM  ZZJ-CHN  TYZ-VNM
# 13824  ZZJ-CHN-ZYN-CHN  ZZJ-CHN  ZYN-CHN
#
# [13825 rows x 3 columns]

# %%
merge1 = dfor[['ID_1', 'ID_2', 'ID_1alt', 'ID_2alt', 'identifier']].merge(borders_geo[['ID_1', 'ID_2']])
merge1alt = dfor[['ID_1alt', 'ID_2alt', 'identifier']].merge(borders_geo[['ID_1', 'ID_2']], 
                                                             left_on=['ID_1alt', 'ID_2alt'], right_on=['ID_1', 'ID_2'])
merged1 = pd.concat([merge1, merge1alt]).reset_index(drop=True)
merged1
# Out:
#           ID_1     ID_2  ID_1alt  ID_2alt       identifier
# 0      AAA-NGA  EMA-NGA  EMA-NGA  AAA-NGA  AAA-NGA-EMA-NGA
# 1      AAB-NGA  JID-NGA  JID-NGA  AAB-NGA  AAB-NGA-JID-NGA
# 2      AAB-NGA  RIN-NGA  RIN-NGA  AAB-NGA  AAB-NGA-RIN-NGA
# 3      AAB-NGA  TDV-NGA  TDV-NGA  AAB-NGA  AAB-NGA-TDV-NGA
# 4      AAC-PNG  DBY-PNG  DBY-PNG  AAC-PNG  AAC-PNG-DBY-PNG
# ...        ...      ...      ...      ...              ...
# 27644  YUE-CHN  ZYN-CHN  YUE-CHN  ZYN-CHN  ZYN-CHN-YUE-CHN
# 27645  CMN-CHN  ZZJ-CHN  CMN-CHN  ZZJ-CHN  ZZJ-CHN-CMN-CHN
# 27646  IUM-CHN  ZZJ-CHN  IUM-CHN  ZZJ-CHN  ZZJ-CHN-IUM-CHN
# 27647  TYZ-VNM  ZZJ-CHN  TYZ-VNM  ZZJ-CHN  ZZJ-CHN-TYZ-VNM
# 27648  ZYN-CHN  ZZJ-CHN  ZYN-CHN  ZZJ-CHN  ZZJ-CHN-ZYN-CHN
#
# [27649 rows x 5 columns]

# %%
merged1.loc[merged1.duplicated(subset=['identifier'])]
# Out:
#           ID_1     ID_2  ID_1alt  ID_2alt       identifier
# 13825  EMA-NGA  AAA-NGA  EMA-NGA  AAA-NGA  AAA-NGA-EMA-NGA
# 13826  JID-NGA  AAB-NGA  JID-NGA  AAB-NGA  AAB-NGA-JID-NGA
# 13827  RIN-NGA  AAB-NGA  RIN-NGA  AAB-NGA  AAB-NGA-RIN-NGA
# 13828  TDV-NGA  AAB-NGA  TDV-NGA  AAB-NGA  AAB-NGA-TDV-NGA
# 13829  DBY-PNG  AAC-PNG  DBY-PNG  AAC-PNG  AAC-PNG-DBY-PNG
# ...        ...      ...      ...      ...              ...
# 27644  YUE-CHN  ZYN-CHN  YUE-CHN  ZYN-CHN  ZYN-CHN-YUE-CHN
# 27645  CMN-CHN  ZZJ-CHN  CMN-CHN  ZZJ-CHN  ZZJ-CHN-CMN-CHN
# 27646  IUM-CHN  ZZJ-CHN  IUM-CHN  ZZJ-CHN  ZZJ-CHN-IUM-CHN
# 27647  TYZ-VNM  ZZJ-CHN  TYZ-VNM  ZZJ-CHN  ZZJ-CHN-TYZ-VNM
# 27648  ZYN-CHN  ZZJ-CHN  ZYN-CHN  ZZJ-CHN  ZZJ-CHN-ZYN-CHN
#
# [13824 rows x 5 columns]

# %%
dfor[['ID_1', 'ID_2', 'ID_1alt', 'ID_2alt', 'identifier']].merge(borders_geo[['ID_1', 'ID_2']], how='left')
# Out:
#           ID_1     ID_2  ID_1alt  ID_2alt       identifier
# 0      AAA-NGA  EMA-NGA  EMA-NGA  AAA-NGA  AAA-NGA-EMA-NGA
# 1      AAA-NGA  OKE-NGA  OKE-NGA  AAA-NGA  AAA-NGA-OKE-NGA
# 2      AAB-NGA  JID-NGA  JID-NGA  AAB-NGA  AAB-NGA-JID-NGA
# 3      AAB-NGA  RIN-NGA  RIN-NGA  AAB-NGA  AAB-NGA-RIN-NGA
# 4      AAB-NGA  TDV-NGA  TDV-NGA  AAB-NGA  AAB-NGA-TDV-NGA
# ...        ...      ...      ...      ...              ...
# 15598  ZYN-CHN  YUE-CHN  YUE-CHN  ZYN-CHN  ZYN-CHN-YUE-CHN
# 15599  ZZJ-CHN  CMN-CHN  CMN-CHN  ZZJ-CHN  ZZJ-CHN-CMN-CHN
# 15600  ZZJ-CHN  IUM-CHN  IUM-CHN  ZZJ-CHN  ZZJ-CHN-IUM-CHN
# 15601  ZZJ-CHN  TYZ-VNM  TYZ-VNM  ZZJ-CHN  ZZJ-CHN-TYZ-VNM
# 15602  ZZJ-CHN  ZYN-CHN  ZYN-CHN  ZZJ-CHN  ZZJ-CHN-ZYN-CHN
#
# [15603 rows x 5 columns]

# %%
dfor[['ID_1', 'ID_2', 'identifier']].merge(non_repeated_pairs[['ID_1', 'ID_2']])
# Out:
#          ID_1     ID_2       identifier
# 0     AAL-CMR  MXF-CMR  AAL-CMR-MXF-CMR
# 1     AAR-DJI  SOM-ETH  AAR-DJI-SOM-ETH
# 2     AAR-ETH  AMH-ETH  AAR-ETH-AMH-ETH
# 3     AAR-ETH  GAX-ETH  AAR-ETH-GAX-ETH
# 4     AAR-ETH  SOM-ETH  AAR-ETH-SOM-ETH
# ...       ...      ...              ...
# 2599  ZYJ-CHN  ZGN-CHN  ZYJ-CHN-ZGN-CHN
# 2600  ZYJ-CHN  ZYB-CHN  ZYJ-CHN-ZYB-CHN
# 2601  ZYJ-CHN  ZZJ-CHN  ZYJ-CHN-ZZJ-CHN
# 2602  ZYN-CHN  CMN-CHN  ZYN-CHN-CMN-CHN
# 2603  ZZJ-CHN  ZYN-CHN  ZZJ-CHN-ZYN-CHN
#
# [2604 rows x 3 columns]

# %%
dfor[['ID_1alt', 'ID_2alt', 'identifier']].merge(borders_geo[['ID_1', 'ID_2']], left_on=['ID_1alt', 'ID_2alt'], right_on=['ID_1', 'ID_2'])
# Out:
#        ID_1alt  ID_2alt       identifier     ID_1     ID_2
# 0      EMA-NGA  AAA-NGA  AAA-NGA-EMA-NGA  EMA-NGA  AAA-NGA
# 1      JID-NGA  AAB-NGA  AAB-NGA-JID-NGA  JID-NGA  AAB-NGA
# 2      RIN-NGA  AAB-NGA  AAB-NGA-RIN-NGA  RIN-NGA  AAB-NGA
# 3      TDV-NGA  AAB-NGA  AAB-NGA-TDV-NGA  TDV-NGA  AAB-NGA
# 4      DBY-PNG  AAC-PNG  AAC-PNG-DBY-PNG  DBY-PNG  AAC-PNG
# ...        ...      ...              ...      ...      ...
# 13819  YUE-CHN  ZYN-CHN  ZYN-CHN-YUE-CHN  YUE-CHN  ZYN-CHN
# 13820  CMN-CHN  ZZJ-CHN  ZZJ-CHN-CMN-CHN  CMN-CHN  ZZJ-CHN
# 13821  IUM-CHN  ZZJ-CHN  ZZJ-CHN-IUM-CHN  IUM-CHN  ZZJ-CHN
# 13822  TYZ-VNM  ZZJ-CHN  ZZJ-CHN-TYZ-VNM  TYZ-VNM  ZZJ-CHN
# 13823  ZYN-CHN  ZZJ-CHN  ZZJ-CHN-ZYN-CHN  ZYN-CHN  ZZJ-CHN
#
# [13824 rows x 5 columns]

# %%
dfor[['ID_1alt', 'ID_2alt', 'identifier']].merge(non_repeated_pairs[['ID_1', 'ID_2']], left_on=['ID_1alt', 'ID_2alt'], right_on=['ID_1', 'ID_2'])
# Out:
#        ID_1alt  ID_2alt       identifier     ID_1     ID_2
# 0      EMA-NGA  AAA-NGA  AAA-NGA-EMA-NGA  EMA-NGA  AAA-NGA
# 1      JID-NGA  AAB-NGA  AAB-NGA-JID-NGA  JID-NGA  AAB-NGA
# 2      RIN-NGA  AAB-NGA  AAB-NGA-RIN-NGA  RIN-NGA  AAB-NGA
# 3      TDV-NGA  AAB-NGA  AAB-NGA-TDV-NGA  TDV-NGA  AAB-NGA
# 4      DBY-PNG  AAC-PNG  AAC-PNG-DBY-PNG  DBY-PNG  AAC-PNG
# ...        ...      ...              ...      ...      ...
# 12459  TYZ-VNM  ZYN-CHN  ZYN-CHN-TYZ-VNM  TYZ-VNM  ZYN-CHN
# 12460  YUE-CHN  ZYN-CHN  ZYN-CHN-YUE-CHN  YUE-CHN  ZYN-CHN
# 12461  CMN-CHN  ZZJ-CHN  ZZJ-CHN-CMN-CHN  CMN-CHN  ZZJ-CHN
# 12462  IUM-CHN  ZZJ-CHN  ZZJ-CHN-IUM-CHN  IUM-CHN  ZZJ-CHN
# 12463  TYZ-VNM  ZZJ-CHN  ZZJ-CHN-TYZ-VNM  TYZ-VNM  ZZJ-CHN
#
# [12464 rows x 5 columns]

# %%
# %%time
non_repeated_pairs_or = drop_repeated(dfor[['ID_1', 'ID_2', 'identifier']], ['ID_1', 'ID_2'])
non_repeated_pairs_or
# Out:
# CPU times: user 4.65 s, sys: 53.6 ms, total: 4.7 s
# Wall time: 4.61 s
#           ID_1     ID_2
# 0      AAA-NGA  EMA-NGA
# 1      AAA-NGA  OKE-NGA
# 2      AAB-NGA  JID-NGA
# 3      AAB-NGA  RIN-NGA
# 4      AAB-NGA  TDV-NGA
# ...        ...      ...
# 15598  ZYN-CHN  YUE-CHN
# 15599  ZZJ-CHN  CMN-CHN
# 15600  ZZJ-CHN  IUM-CHN
# 15601  ZZJ-CHN  TYZ-VNM
# 15602  ZZJ-CHN  ZYN-CHN
#
# [15603 rows x 2 columns]

# %% [markdown]
# Identify missing indentifiers

# %%
missing = list(set(dfor.identifier).difference(borders_geo.identifier))
missing.sort()
len(missing)
# Out:
# 1778

# %%
missing[0]
# Out:
# 'AAA-NGA-OKE-NGA'

# %%
pairs.loc[pairs.ID_1==missing[0][:7], ['ID_1', 'ID_2']]
# Out:
#           ID_1     ID_2
# 47364  AAA-NGA  YOR-NGA
# 47615  AAA-NGA  BIN-NGA
# 47676  AAA-NGA  IGB-NGA
# 47680  AAA-NGA  ISH-NGA
# 47754  AAA-NGA  ETS-NGA
# 48194  AAA-NGA  OPA-NGA
# 48361  AAA-NGA  EMA-NGA
# 48502  AAA-NGA  ATG-NGA
# 49143  AAA-NGA  IKP-NGA
# 49147  AAA-NGA  IYA-NGA
# 49152  AAA-NGA  UHA-NGA
# 49382  AAA-NGA  IDS-NGA
# 49396  AAA-NGA  IGW-NGA
# 49635  AAA-NGA  ENV-NGA
# 49638  AAA-NGA  OKX-NGA
# 49884  AAA-NGA  UNE-NGA
# 49886  AAA-NGA  SXS-NGA

# %%
ethno.loc[ethno.ID==missing[0][:7]]
# Out:
#            ID ID_ISO_A3 ID_ISO_A2 ID_FIPS NAM_LABEL NAME_PROP   NAME2 NAM_ANSI     CNT       C1   POP  LMP_POP1  \
# 5269  AAA-NGA   aaa-NGA    aaa-ng  aaa-NI    Ghotuo    Ghotuo  GHOTUO   Ghotuo  Africa  Nigeria  9000    9000.0
#
#                                                       G LMP_CLASS   FAMILYPROP       FAMILY   LMP_C1 LANG_ISO EGIDS  \
# 5269  Niger-Congo, Atlantic-Congo, Volta-Congo, Benu...         L  Niger-Congo  NIGER-CONGO  Nigeria      aaa    6a
#
#                                                geometry
# 5269  POLYGON ((6.02072 7.15994, 6.02974 7.08112, 6....

# %%
ethno.loc[ethno.ID==missing[0][:7]].plot()
# Out:
# <AxesSubplot:>

# %%
A = ethno.loc[ethno.ID==missing[0][:7], 'geometry'].values[0]
B = ethno.loc[ethno.ID==missing[0][8:], 'geometry'].values[0]
print(A.intersects(B))
print(A.buffer(0.2).intersects(B))
A.buffer(0.2).intersection(B.boundary)
# Out:
# False
# False
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# <LINESTRING Z EMPTY>

# %%
ethno.loc[ethno.ID==missing[0][8:]]
# Out:
#            ID ID_ISO_A3 ID_ISO_A2 ID_FIPS NAM_LABEL NAME_PROP NAME2 NAM_ANSI     CNT       C1    POP  LMP_POP1  \
# 6637  OKE-NGA   oke-NGA    oke-ng  oke-NI      Okpe      Okpe  OKPE     Okpe  Africa  Nigeria  25400   25400.0
#
#                                                       G LMP_CLASS   FAMILYPROP       FAMILY   LMP_C1 LANG_ISO EGIDS  \
# 6637  Niger-Congo, Atlantic-Congo, Volta-Congo, Benu...         L  Niger-Congo  NIGER-CONGO  Nigeria      oke    6a
#
#                                                geometry
# 6637  POLYGON ((5.97268 5.41408, 5.93522 5.40111, 5....

# %%
ethno.loc[ethno.ID==missing[0][8:]].plot()
# Out:
# <AxesSubplot:>

# %%
ethno.loc[(ethno.ID==missing[0][:7])|(ethno.ID==missing[0][8:])].plot()
# Out:
# <AxesSubplot:>

# %%
pairs.loc[(pairs.ID_1==missing[0][:7])&(pairs.ID_2==missing[0][8:])]
# Out:
# Empty DataFrame
# Columns: [ID_1, ID_ISO_A3_1, ID_ISO_A2_1, ID_FIPS_1, NAM_LABEL_1, NAME_PROP_1, NAME2_1, NAM_ANSI_1, CNT_1, C1_1, POP_1, LMP_POP1_1, G_1, LMP_CLASS_1, FAMILYPROP_1, FAMILY_1, LMP_C1_1, LANG_ISO_1, EGIDS_1, geometry_1, index_2, ID_2, ID_ISO_A3_2, ID_ISO_A2_2, ID_FIPS_2, NAM_LABEL_2, NAME_PROP_2, NAME2_2, NAM_ANSI_2, CNT_2, C1_2, POP_2, LMP_POP1_2, G_2, LMP_CLASS_2, FAMILYPROP_2, FAMILY_2, LMP_C1_2, LANG_ISO_2, EGIDS_2, ID, geometry_2]
# Index: []
#
# [0 rows x 42 columns]

# %%
pairs.loc[(pairs.ID_2==missing[0][:7])&(pairs.ID_1==missing[0][8:])]
# Out:
# Empty DataFrame
# Columns: [ID_1, ID_ISO_A3_1, ID_ISO_A2_1, ID_FIPS_1, NAM_LABEL_1, NAME_PROP_1, NAME2_1, NAM_ANSI_1, CNT_1, C1_1, POP_1, LMP_POP1_1, G_1, LMP_CLASS_1, FAMILYPROP_1, FAMILY_1, LMP_C1_1, LANG_ISO_1, EGIDS_1, geometry_1, index_2, ID_2, ID_ISO_A3_2, ID_ISO_A2_2, ID_FIPS_2, NAM_LABEL_2, NAME_PROP_2, NAME2_2, NAM_ANSI_2, CNT_2, C1_2, POP_2, LMP_POP1_2, G_2, LMP_CLASS_2, FAMILYPROP_2, FAMILY_2, LMP_C1_2, LANG_ISO_2, EGIDS_2, ID, geometry_2]
# Index: []
#
# [0 rows x 42 columns]

# %%
missing[0][:7]
# Out:
# 'AAA-NGA'

# %%
missing[0][8:]
# Out:
# 'OKE-NGA'

# %% [markdown]
# These are missing because they are the same language but in two countries, or because the polygon is missing in v17 or as in example above in v17 they are not touching.

# %%
same_lang_miss = []
diff_lang_miss = []
for m in missing:
    if m[:3]==m[8:11]:
        same_lang_miss.append(m)
    else:
        diff_lang_miss.append(m)

# %%
len(diff_lang_miss)
# Out:
# 1693

# %%
diff_lang_miss
# Out:
# ['AAA-NGA-OKE-NGA',
#  'AAL-NGA-KNC-NGA',
#  'AAL-NGA-KOT-CMR',
#  'AAL-NGA-SHU-CMR',
#  'ABF-MYS-DBJ-MYS',
#  'ABF-MYS-TSG-MYS',
#  'ABQ-RUS-ADY-RUS',
#  'ACC-GTM-QUC-GTM',
#  'ACH-SDN-LOT-SDN',
#  'ACH-SDN-MHI-SDN',
#  'AEC-EGY-KZH-EGY',
#  'AFB-YEM-AYH-YEM',
#  'AFB-YEM-GDQ-YEM',
#  'AGB-NGA-IZI-NGA',
#  'AGB-NGA-ORG-NGA',
#  'AGC-NGA-GBY-NGA',
#  'AGH-COD-NGC-COD',
#  'AGP-PHL-DGC-PHL',
#  'AGP-PHL-DUO-PHL',
#  'AGP-PHL-ILO-PHL',
#  'AGZ-PHL-BHK-PHL',
#  'AHK-THA-LIS-MMR',
#  'AII-TUR-AYP-SYR',
#  'AII-TUR-AYP-TUR',
#  'AIM-IND-LIF-IND',
#  'AIM-IND-LIF-NPL',
#  'AIM-IND-NEP-IND',
#  'AIM-IND-NMF-IND',
#  'AJA-SDN-KRS-SDN',
#  'AJA-SDN-YUL-SDN',
#  'ALL-IND-KEJ-IND',
#  'ALS-ALB-MKD-GRC',
#  'ALY-AUS-ARE-AUS',
#  'AMO-NGA-GNH-NGA',
#  'AMQ-IDN-WEO-IDN',
#  'AMT-PNG-SUG-PNG',
#  'ANC-NGA-CLA-NGA',
#  'ANC-NGA-KUL-NGA',
#  'ANL-MMR-PRK-MMR',
#  'ANL-MMR-SHN-MMR',
#  'ANM-IND-MNI-MMR',
#  'ANM-IND-ZOM-IND',
#  'ANR-IND-LMN-IND',
#  'ANR-IND-TEL-IND',
#  'ANU-SDN-NUS-ETH',
#  'ANU-SDN-NUS-SDN',
#  'APC-LBN-ARS-SYR',
#  'APH-NPL-MAI-NPL',
#  'APH-NPL-MGP-NPL',
#  'APL-USA-APM-USA',
#  'APL-USA-ENG-USA',
#  'APT-IND-ADI-IND',
#  'APT-IND-ASM-IND',
#  'APT-IND-DAP-IND',
#  'APX-IDN-ILW-IDN',
#  'ASB-CAN-ENG-CAN',
#  'ASB-USA-ENG-USA',
#  'ASM-IND-SDR-BGD',
#  'ASR-IND-BEN-IND',
#  'ASR-IND-HNE-IND',
#  'ASR-IND-KRU-IND',
#  'ASR-IND-ORI-IND',
#  'ATB-MMR-LIS-MMR',
#  'ATL-PHL-BHK-PHL',
#  'ATS-USA-ASB-USA',
#  'ATU-SDN-BEX-SDN',
#  'ATU-SDN-BLM-SDN',
#  'ATU-SDN-DIB-SDN',
#  'ATW-USA-ENG-USA',
#  'ATW-USA-NMU-USA',
#  'AVA-RUS-XAL-RUS',
#  'AVU-COD-MUH-SDN',
#  'AVU-SDN-BDH-SDN',
#  'AVU-SDN-BFA-SDN',
#  'AVU-SDN-MGD-SDN',
#  'AVU-SDN-MUH-SDN',
#  'AWA-IND-NEP-NPL',
#  'AWA-NPL-NEP-NPL',
#  'AYO-BOL-SPA-PRY',
#  'AYO-PRY-SPA-PRY',
#  'AYX-CHN-LIS-CHN',
#  'BAO-BRA-POR-BRA',
#  'BAP-NPL-NEP-NPL',
#  'BAU-NGA-FUV-NGA',
#  'BAZ-CMR-BAS-CMR',
#  'BAZ-CMR-BAX-CMR',
#  'BBM-COD-NGC-COD',
#  'BBP-SDN-BVI-SDN',
#  'BBP-SDN-LWO-SDN',
#  'BBV-PNG-SPL-PNG',
#  'BBV-PNG-TIM-PNG',
#  'BCS-NGA-ORG-NGA',
#  'BCV-NGA-FUB-NGA',
#  'BCY-NGA-FUB-NGA',
#  'BDG-MYS-BDR-MYS',
#  'BDG-MYS-SSB-MYS',
#  'BDH-COD-MUH-SDN',
#  'BDH-COD-ZNE-SDN',
#  'BDH-SDN-MUH-SDN',
#  'BDH-SDN-ZNE-SDN',
#  'BDI-SDN-DIP-SDN',
#  'BDJ-SDN-THU-SDN',
#  'BDM-NGA-KBL-TCD',
#  'BDR-MYS-DBJ-MYS',
#  'BDR-MYS-DPP-MYS',
#  'BDR-MYS-DRG-MYS',
#  'BDR-MYS-DTP-MYS',
#  'BDR-MYS-SSB-MYS',
#  'BDR-MYS-TSG-MYS',
#  'BDV-IND-ORI-IND',
#  'BDZ-PAK-TRW-PAK',
#  'BDZ-PAK-USH-PAK',
#  'BEB-CMR-FAN-CMR',
#  'BEE-NPL-NEP-NPL',
#  'BEM-COD-AUH-ZMB',
#  'BEN-BGD-ASM-BGD',
#  'BEN-IND-ASM-BGD',
#  'BEN-IND-ORI-IND',
#  'BEN-NPL-HIN-IND',
#  'BEN-NPL-RWR-NPL',
#  'BEX-SDN-DIB-SDN',
#  'BEX-SDN-MGD-SDN',
#  'BFA-UGA-KEO-SDN',
#  'BFQ-IND-KFI-IND',
#  'BFW-IND-KXV-IND',
#  'BFW-IND-SRB-IND',
#  'BFY-IND-MAR-IND',
#  'BFY-NPL-BEN-NPL',
#  'BFY-NPL-HIN-IND',
#  'BFY-NPL-MAI-NPL',
#  'BFY-NPL-RJS-NPL',
#  'BFY-NPL-THQ-NPL',
#  'BFZ-IND-PAN-IND',
#  'BGC-IND-PAN-IND',
#  'BGC-IND-RWR-IND',
#  'BGD-IND-KHN-IND',
#  'BGR-MMR-CNH-MMR',
#  'BGR-MMR-CNW-MMR',
#  'BGR-MMR-CZT-MMR',
#  'BGR-MMR-MRH-IND',
#  'BGR-MMR-MWQ-MMR',
#  'BGW-IND-GNO-IND',
#  'BGW-IND-HNE-IND',
#  'BGW-IND-ORI-IND',
#  'BGX-TUR-TUR-TUR',
#  'BHA-IND-HNE-IND',
#  'BHB-IND-MAR-IND',
#  'BHK-PHL-BCL-PHL',
#  'BHO-NPL-AWA-IND',
#  'BHO-NPL-NEP-NPL',
#  'BHU-IND-ORI-IND',
#  'BIJ-NGA-ZAZ-NGA',
#  'BIS-NCL-KDK-NCL',
#  'BIU-IND-DHO-IND',
#  'BIU-IND-DUB-IND',
#  'BIU-IND-GUJ-IND',
#  'BIX-IND-KHR-IND',
#  'BIX-IND-KRU-IND',
#  'BIX-IND-ORI-IND',
#  'BIY-IND-TDB-IND',
#  'BJD-AUS-ENG-AUS',
#  'BJQ-MDG-BMM-MDG',
#  'BJQ-MDG-PLT-MDG',
#  'BJQ-MDG-TXY-MDG',
#  'BJR-PNG-KYY-PNG',
#  'BKB-PHL-BLW-PHL',
#  'BKB-PHL-BNC-PHL',
#  'BKB-PHL-IFA-PHL',
#  'BKN-MYS-PNE-MYS',
#  'BKO-CMR-BAZ-CMR',
#  'BLK-MMR-PWO-MMR',
#  'BLM-SDN-BEX-SDN',
#  'BLM-SDN-DIB-SDN',
#  'BLR-MMR-LIS-MMR',
#  'BLW-PHL-BNC-PHL',
#  'BMJ-NPL-NEP-NPL',
#  'BNB-MYS-DMG-MYS',
#  'BNB-MYS-PLZ-MYS',
#  'BNC-PHL-KNE-PHL',
#  'BNI-COD-AXK-COG',
#  'BNS-IND-GUJ-IND',
#  'BNS-IND-MAR-IND',
#  'BOA-BRA-POR-BRA',
#  'BOA-BRA-TCA-BRA',
#  'BOD-BTN-DZO-BTN',
#  'BOD-BTN-KJZ-BTN',
#  'BOD-IND-NEP-IND',
#  'BOD-IND-NEP-NPL',
#  'BOD-NPL-LIF-NPL',
#  'BOD-NPL-NEP-NPL',
#  'BOH-COD-BWW-COD',
#  'BOH-COD-NGB-COD',
#  'BOH-COD-PAE-COD',
#  'BOM-NGA-KUL-NGA',
#  'BOT-SDN-BVI-SDN',
#  'BOT-SDN-BXB-SDN',
#  'BOT-SDN-DIK-SDN',
#  'BOT-SDN-LWO-SDN',
#  'BPG-IDN-JBR-IDN',
#  'BPK-NCL-SIH-NCL',
#  'BRD-NPL-BOD-CHN',
#  'BRD-NPL-BOD-NPL',
#  'BRX-IND-KRU-IND',
#  'BRX-IND-NEP-BTN',
#  'BRX-IND-NEP-IND',
#  'BRX-IND-SAT-IND',
#  'BRX-IND-UNR-IND',
#  'BRX-NPL-NEP-IND',
#  'BRX-NPL-NEP-NPL',
#  'BST-ETH-GMO-ETH',
#  'BSX-NGA-BAU-NGA',
#  'BSX-NGA-JAR-NGA',
#  'BSY-MYS-TIH-MYS',
#  'BTA-CMR-FUB-NGA',
#  'BTA-NGA-FUB-NGA',
#  'BTO-PHL-BHK-PHL',
#  'BTQ-MYS-SEA-MYS',
#  'BUX-NGA-JAR-NGA',
#  'BVI-SDN-BXB-SDN',
#  'BVI-SDN-LWO-SDN',
#  'BVI-SDN-THU-SDN',
#  'BVW-NGA-FUB-NGA',
#  'BVW-NGA-MFL-NGA',
#  'BVW-NGA-MFM-NGA',
#  'BVW-NGA-MRT-NGA',
#  'BWE-MMR-KSW-THA',
#  'BWI-BRA-KPC-BRA',
#  'BWR-NGA-FUB-NGA',
#  'BWW-COD-NGC-COD',
#  'BXU-CHN-CMN-CHN',
#  'BYH-NPL-NEP-NPL',
#  'BYM-AUS-ENG-AUS',
#  'BYV-CMR-BAZ-CMR',
#  'BZE-MLI-DKL-MLI',
#  'BZI-THA-AHK-THA',
#  'BZI-THA-NOD-THA',
#  'CAG-PRY-LEG-PRY',
#  'CAG-PRY-SPA-PRY',
#  'CAH-PER-SPA-PER',
#  'CAR-BRA-POR-BRA',
#  'CBM-GTM-CAK-GTM',
#  'CBM-GTM-CKD-GTM',
#  'CBM-GTM-CKF-GTM',
#  'CBM-GTM-SPA-GTM',
#  'CCG-NGA-FUB-NGA',
#  'CCJ-GNB-BCZ-SEN',
#  'CCJ-GNB-BLE-GNB',
#  'CCJ-GNB-DYO-SEN',
#  'CCJ-GNB-KCJ-GNB',
#  'CCJ-GNB-KNF-SEN',
#  'CCJ-GNB-MFV-GNB',
#  'CCJ-GNB-MNK-GNB',
#  'CCJ-GNB-MNK-SEN',
#  'CCQ-MMR-MYA-MMR',
#  'CDF-IND-NMF-IND',
#  'CDF-IND-NRI-IND',
#  'CDF-IND-NSA-IND',
#  'CDF-IND-YIM-IND',
#  'CDG-IND-BFY-IND',
#  'CDI-IND-BHB-IND',
#  'CDM-NPL-NEP-NPL',
#  'CDN-IND-NEP-NPL',
#  'CDN-NPL-NEP-NPL',
#  'CDR-NGA-DUD-NGA',
#  'CES-CZE-DEU-AUT',
#  'CFG-NGA-FUB-NGA',
#  'CFM-IND-CTD-IND',
#  'CFM-IND-CTD-MMR',
#  'CHX-NPL-MRD-NPL',
#  'CKA-MMR-CNB-MMR',
#  'CKA-MMR-CNK-MMR',
#  'CKA-MMR-DAO-MMR',
#  'CKA-MMR-RKI-MMR',
#  'CKC-GTM-CAK-GTM',
#  'CKC-GTM-CKD-GTM',
#  'CKC-GTM-CKE-GTM',
#  'CKD-GTM-CAK-GTM',
#  'CKD-GTM-CKE-GTM',
#  'CKD-GTM-SPA-GTM',
#  'CKE-GTM-ACC-GTM',
#  'CKE-GTM-ACR-GTM',
#  'CKE-GTM-SPA-GTM',
#  'CKF-GTM-CKD-GTM',
#  'CKF-GTM-SPA-GTM',
#  'CKH-BGD-MYA-BGD',
#  'CKH-MMR-CNK-MMR',
#  'CKH-MMR-CZT-MMR',
#  'CKH-MMR-LUS-IND',
#  'CKI-GTM-CKF-GTM',
#  'CKJ-GTM-SPA-GTM',
#  'CKK-GTM-CKF-GTM',
#  'CKW-GTM-CAK-GTM',
#  'CKW-GTM-QUC-GTM',
#  'CKZ-GTM-CKD-GTM',
#  'CLL-GHA-NTR-GHA',
#  'CNB-MMR-MWQ-MMR',
#  'CNB-MMR-YBD-MMR',
#  'CNK-MMR-MYA-MMR',
#  'CNM-GTM-SPA-GTM',
#  'CNM-GTM-SPA-MEX',
#  'CNM-MEX-MAM-GTM',
#  'CNM-MEX-SPA-MEX',
#  'CNW-MMR-CNK-MMR',
#  'CNW-MMR-MWQ-MMR',
#  'COA-MYS-DBJ-MYS',
#  'COA-MYS-DTB-MYS',
#  'COA-MYS-SSB-MYS',
#  'COA-MYS-TSG-MYS',
#  'COA-MYS-TXA-MYS',
#  'COD-BRA-BOA-BRA',
#  'COD-BRA-POR-BRA',
#  'COD-BRA-TCA-BRA',
#  'COD-BRA-TCA-PER',
#  'COD-COL-SPA-COL',
#  'COG-KHM-KHM-KHM',
#  'COG-KHM-KXM-THA',
#  'COG-KHM-SMU-KHM',
#  'COG-KHM-THA-THA',
#  'COG-KHM-TTS-THA',
#  'CRA-ETH-GMO-ETH',
#  'CRK-USA-ASB-USA',
#  'CRQ-BOL-CAG-ARG',
#  'CRQ-BOL-MTP-BOL',
#  'CRQ-BOL-MZH-ARG',
#  'CRQ-BOL-TPJ-BOL',
#  'CRQ-BOL-TPJ-PRY',
#  'CRQ-PRY-SPA-PRY',
#  'CSA-MEX-CHJ-MEX',
#  'CSA-MEX-SPA-MEX',
#  'CSH-MMR-MWQ-MMR',
#  'CSY-MMR-PCK-MMR',
#  'CSY-MMR-TCZ-MMR',
#  'CSZ-USA-ENG-USA',
#  'CTI-MEX-SPA-MEX',
#  'CUN-GTM-QUV-GTM',
#  'CUR-NPL-MAI-NPL',
#  'CUR-NPL-MGP-NPL',
#  'CWE-TZA-ZAJ-TZA',
#  'CWG-MYS-JAH-MYS',
#  'CWG-MYS-SEA-MYS',
#  'CZT-MMR-CFM-MMR',
#  'CZT-MMR-CNH-MMR',
#  'CZT-MMR-LUS-MMR',
#  'DAF-CIV-GXX-CIV',
#  'DAF-CIV-MKU-GIN',
#  'DAF-LBR-KRW-LBR',
#  'DAH-PNG-BBV-PNG',
#  'DAO-MMR-CNK-MMR',
#  'DAP-IND-ADI-IND',
#  'DAP-IND-ASM-IND',
#  'DAP-IND-CLK-IND',
#  'DAQ-IND-GNO-IND',
#  'DAV-KEN-MAS-TZA',
#  'DBB-NGA-FUV-NGA',
#  'DBG-MLI-DKL-MLI',
#  'DBI-NGA-IKV-NGA',
#  'DBI-NGA-KHJ-NGA',
#  'DBM-NGA-FUV-NGA',
#  'DBO-NGA-BAU-NGA',
#  'DBO-NGA-JAR-NGA',
#  'DCC-IND-LMN-IND',
#  'DDD-SDN-DID-SDN',
#  'DDD-SDN-LNO-SDN',
#  'DDD-SDN-LOH-SDN',
#  'DDD-SDN-LOT-SDN',
#  'DDS-MLI-DKL-MLI',
#  'DEC-SDN-APD-SDN',
#  'DEC-SDN-JLE-SDN',
#  'DEC-SDN-KGO-SDN',
#  'DER-IND-APT-IND',
#  'DEU-AUT-CES-AUT',
#  'DEU-AUT-FRL-ITA',
#  'DEU-AUT-HUN-HUN',
#  'DEU-AUT-ITA-ITA',
#  'DEU-AUT-VEC-ITA',
#  'DGB-MLI-DKL-MLI',
#  'DGE-PNG-BBV-PNG',
#  'DGO-IND-PHR-PAK',
#  'DHI-NPL-NEP-NPL',
#  'DHN-IND-BHB-IND',
#  'DHO-IND-BHB-IND',
#  'DHW-NPL-CDM-NPL',
#  'DHW-NPL-THE-NPL',
#  'DIB-SDN-DIK-SDN',
#  'DIB-SDN-NUS-SDN',
#  'DID-SDN-KDJ-UGA',
#  'DID-SDN-TOQ-SDN',
#  'DIG-TZA-MAS-TZA',
#  'DIK-SDN-APD-SDN',
#  'DIK-SDN-NUS-SDN',
#  'DIP-SDN-APD-SDN',
#  'DIP-SDN-NUS-SDN',
#  'DIS-IND-MJW-IND',
#  'DIU-AGO-NBA-AGO',
#  'DIU-AGO-NDO-AGO',
#  'DIW-SDN-APD-SDN',
#  'DIW-SDN-DIK-SDN',
#  'DIW-SDN-DIP-SDN',
#  'DIW-SDN-NUS-SDN',
#  'DJD-AUS-GDH-AUS',
#  'DKL-MLI-DTK-MLI',
#  'DKL-MLI-DTM-MLI',
#  'DKR-MYS-DTP-MYS',
#  'DKR-MYS-KXI-MYS',
#  'DKS-SDN-DIB-SDN',
#  'DKS-SDN-MUR-SDN',
#  'DKS-SDN-NUS-SDN',
#  'DMG-MYS-DBJ-MYS',
#  'DMG-MYS-DTB-MYS',
#  'DMG-MYS-SSB-MYS',
#  'DMG-MYS-TSG-MYS',
#  'DMV-MYS-COA-MYS',
#  'DMV-MYS-DTB-MYS',
#  'DOH-NGA-FUB-NGA',
#  'DOT-NGA-BAU-NGA',
#  'DOT-NGA-DBM-NGA',
#  'DOT-NGA-JAR-NGA',
#  'DOT-NGA-ZAZ-NGA',
#  'DOZ-ETH-GMO-ETH',
#  'DRD-IND-NEP-NPL',
#  'DRD-NPL-NEP-NPL',
#  'DRE-NPL-NEP-NPL',
#  'DRG-MYS-TXA-MYS',
#  'DRH-MNG-XAL-MNG',
#  'DRW-AFG-TGK-TJK',
#  'DRY-NPL-KRA-NPL',
#  'DSN-IDN-WAD-IDN',
#  'DTB-MYS-LOW-MYS',
#  'DTM-MLI-DJM-MLI',
#  'DTP-MYS-DTB-MYS',
#  'DTP-MYS-LOW-MYS',
#  'DTR-MYS-DTP-MYS',
#  'DWL-MLI-DBU-MLI',
#  'DWL-MLI-DJM-MLI',
#  'DYN-AUS-ENG-AUS',
#  'DZO-NPL-NEW-NPL',
#  'DZO-NPL-TAJ-NPL',
#  'EBO-COD-LOL-COD',
#  'EBO-COD-SKT-COD',
#  'EBO-COD-TEK-COD',
#  'EKY-THA-KYU-MMR',
#  'ELL-EGY-ARZ-EGY',
#  'EMG-NPL-LBR-NPL',
#  'EMK-GIN-BAM-MLI',
#  'EML-ITA-LMO-ITA',
#  'ENV-NGA-OKE-NGA',
#  'ESI-USA-ENG-USA',
#  'ESI-USA-ESK-USA',
#  'ESK-USA-ENG-USA',
#  'EST-EST-LAV-LVA',
#  'EST-EST-RUS-RUS',
#  'ETO-CMR-FAN-CMR',
#  'EVN-CHN-CMN-CHN',
#  'EWO-CMR-BKC-CMR',
#  'EWO-CMR-FAN-GAB',
#  'EZE-NGA-IZI-NGA',
#  'FAM-NGA-FUB-NGA',
#  'FAN-GNQ-BUM-CMR',
#  'FAN-GNQ-EWO-CMR',
#  'FER-SDN-KRS-SDN',
#  'FER-SDN-NJL-SDN',
#  'FER-SDN-YUL-SDN',
#  'FGR-TCD-DAU-TCD',
#  'FGR-TCD-FVR-SDN',
#  'FGR-TCD-ROU-CAF',
#  'FGR-TCD-ROU-TCD',
#  'FIE-NGA-ZAZ-NGA',
#  'FIN-RUS-EST-EST',
#  'FMU-IND-GGO-IND',
#  'FMU-IND-GNO-IND',
#  'FMU-IND-MUT-IND',
#  'FRL-ITA-VEC-ITA',
#  'FRQ-PNG-BBV-PNG',
#  'FUV-NGA-BOL-NGA',
#  'FUV-NGA-BXQ-NGA',
#  'FUV-NGA-HAU-NGA',
#  'GAQ-IND-GDB-IND',
#  'GAQ-IND-PCI-IND',
#  'GAS-IND-GRA-IND',
#  'GAS-IND-WBR-IND',
#  'GAV-PNG-DEV-PNG',
#  'GBC-AUS-ENG-AUS',
#  'GBC-AUS-WMB-AUS',
#  'GBF-PNG-SIC-PNG',
#  'GBL-IND-DHO-IND',
#  'GBL-IND-NOI-IND',
#  'GBL-IND-VAS-IND',
#  'GBN-SDN-BEX-SDN',
#  'GBN-SDN-BLM-SDN',
#  'GDB-IND-ORI-IND',
#  'GDB-IND-PCI-IND',
#  'GDH-AUS-ENG-AUS',
#  'GDH-AUS-MEP-AUS',
#  'GDH-AUS-NBJ-AUS',
#  'GDU-NGA-FUB-NGA',
#  'GEA-NGA-FUV-NGA',
#  'GEW-NGA-BAU-NGA',
#  'GEW-NGA-BOL-NGA',
#  'GEW-NGA-JAR-NGA',
#  'GGB-LBR-DAF-LBR',
#  'GGN-NPL-BOD-NPL',
#  'GGO-IND-LMN-IND',
#  'GHE-NPL-GVR-NPL',
#  'GHT-NPL-BOD-NPL',
#  'GHT-NPL-BRD-NPL',
#  'GIN-RUS-CHE-RUS',
#  'GIN-RUS-CJI-RUS',
#  'GIN-RUS-TIN-RUS',
#  'GIO-CHN-CMN-CHN',
#  'GIO-CHN-HNJ-CHN',
#  'GIO-CHN-HUJ-CHN',
#  'GIO-CHN-PCC-CHN',
#  'GIO-CHN-YIG-CHN',
#  'GIO-CHN-ZGN-CHN',
#  'GJI-NGA-FUV-NGA',
#  'GLO-NGA-BAU-NGA',
#  'GLO-NGA-FUV-NGA',
#  'GLO-NGA-JAR-NGA',
#  'GMO-ETH-GAZ-ETH',
#  'GNE-NGA-KUL-NGA',
#  'GNO-IND-BFY-IND',
#  'GNO-IND-HNE-IND',
#  'GNO-IND-MAR-IND',
#  'GNO-IND-MUT-IND',
#  'GNO-IND-ORI-IND',
#  'GNO-IND-TEL-IND',
#  'GNQ-MYS-KXI-MYS',
#  'GOK-IND-KFQ-IND',
#  'GQA-NGA-FUB-NGA',
#  'GRA-IND-RWR-IND',
#  'GRD-NGA-JAR-NGA',
#  'GRK-TUR-TUR-TUR',
#  'GRM-MYS-DTP-MYS',
#  'GRM-MYS-KQR-MYS',
#  'GRR-DZA-TIA-DZA',
#  'GRT-IND-SDR-BGD',
#  'GSW-CHE-DEU-AUT',
#  'GSW-LIE-DEU-AUT',
#  'GUI-PRY-SPA-PRY',
#  'GUJ-IND-RWR-IND',
#  'GUN-ARG-SPA-PRY',
#  'GUN-BRA-XET-BRA',
#  'GUN-PRY-SPA-PRY',
#  'GUQ-PRY-SPA-PRY',
#  'GVA-PRY-SAP-PRY',
#  'GVP-BRA-POR-BRA',
#  'GVR-NPL-NEP-NPL',
#  'GWE-TZA-MAS-TZA',
#  'GYE-NGA-FUV-NGA',
#  'GYI-GNQ-BUM-CMR',
#  'GYI-GNQ-EWO-CMR',
#  'GYL-ETH-GMO-ETH',
#  'GZA-ETH-BWO-ETH',
#  'GZA-ETH-GUK-ETH',
#  'GZA-ETH-WTI-ETH',
#  'HAJ-IND-SDR-BGD',
#  'HAL-LAO-BRB-KHM',
#  'HBB-NGA-FUB-NGA',
#  'HDY-ETH-GMO-ETH',
#  'HEB-ISR-ARS-SYR',
#  'HIN-NPL-BHO-IND',
#  'HIN-NPL-BHO-NPL',
#  'HIN-NPL-RWR-NPL',
#  'HMG-CHN-GIO-CHN',
#  'HMR-IND-PCK-IND',
#  'HMR-IND-TCZ-IND',
#  'HMY-CHN-GIO-CHN',
#  'HNE-IND-ORI-IND',
#  'HNJ-MMR-LIS-MMR',
#  'HOC-IND-ORI-IND',
#  'HOC-IND-SAT-IND',
#  'HOC-IND-SCK-IND',
#  'HOC-IND-UNR-IND',
#  'HOL-AGO-KMB-AGO',
#  'HOL-COD-KMB-AGO',
#  'HOY-IND-BFY-IND',
#  'HPO-MMR-MYA-MMR',
#  'HPO-MMR-SHN-MMR',
#  'HRA-MMR-CSY-MMR',
#  'HRA-MMR-CTD-MMR',
#  'HRA-MMR-TCZ-MMR',
#  'HRV-AUT-DEU-AUT',
#  'HRV-ITA-ITA-ITA',
#  'HSF-MEX-NHE-MEX',
#  'HSF-MEX-SPA-MEX',
#  'HTI-IDN-BGY-IDN',
#  'HUK-IDN-ALP-IDN',
#  'HUK-IDN-WEO-IDN',
#  'HUT-NPL-NEP-NPL',
#  'HVA-MEX-NHW-MEX',
#  'HVA-MEX-SPA-MEX',
#  'HWO-NGA-FUB-NGA',
#  'IAP-BRA-POR-BRA',
#  'IBI-NGA-OKS-NGA',
#  'IBI-NGA-OPA-NGA',
#  'IBI-NGA-OSO-NGA',
#  'ICH-NGA-FUB-NGA',
#  'ICH-NGA-JBU-NGA',
#  'IDR-SDN-APD-SDN',
#  'IDS-NGA-ETS-NGA',
#  'IFA-PHL-BNC-PHL',
#  'IKL-NGA-GBR-NGA',
#  'IKV-NGA-KRH-NGA',
#  'ILB-ZMB-LEH-ZMB',
#  'IME-MRT-MEY-MRT',
#  'INH-RUS-KRC-RUS',
#  'IRU-IND-KFI-IND',
#  'ISU-CMR-JBU-NGA',
#  'ITA-SMR-EML-ITA',
#  'IXI-GTM-KJB-GTM',
#  'IXI-GTM-QUC-GTM',
#  'IXI-GTM-SPA-GTM',
#  'IXJ-GTM-KEK-GTM',
#  'IXJ-GTM-KJB-GTM',
#  'IXJ-GTM-SPA-GTM',
#  'IYO-CMR-JBU-NGA',
#  'IZH-RUS-EST-EST',
#  'IZI-NGA-IBO-NGA',
#  'IZI-NGA-IDU-NGA',
#  'IZR-NGA-BAU-NGA',
#  'IZR-NGA-DBM-NGA',
#  'IZR-NGA-JAR-NGA',
#  'JAC-GTM-MVJ-GTM',
#  'JAF-NGA-FUV-NGA',
#  'JAH-MYS-BTQ-MYS',
#  'JAH-MYS-SEA-MYS',
#  'JAH-MYS-SZA-MYS',
#  'JAH-MYS-SZC-MYS',
#  'JAH-MYS-ZLM-MYS',
#  'JAI-GTM-CNM-GTM',
#  'JAI-GTM-KNJ-GTM',
#  'JAI-GTM-MAM-GTM',
#  'JAI-GTM-SPA-MEX',
#  'JAI-MEX-SPA-MEX',
#  'JAK-MYS-SZA-MYS',
#  'JAK-MYS-ZLM-MYS',
#  'JAO-AUS-GBC-AUS',
#  'JAR-NGA-FUV-NGA',
#  'JAR-NGA-HAU-NGA',
#  'JAS-NCL-BIS-NCL',
#  'JAS-NCL-KDK-NCL',
#  'JAV-IDN-PEA-IDN',
#  'JBU-NGA-BYF-NGA',
#  'JBU-NGA-FUB-NGA',
#  'JBU-NGA-TIV-NGA',
#  'JEE-NPL-SMM-NPL',
#  'JEN-NGA-FUB-NGA',
#  'JER-NGA-BAU-NGA',
#  'JER-NGA-DBM-NGA',
#  'JER-NGA-JAR-NGA',
#  'JKU-NGA-FUV-NGA',
#  'JKU-NGA-GJI-NGA',
#  'JKU-NGA-GUA-NGA',
#  'JML-NPL-NEP-NPL',
#  'JMS-NGA-JBU-NGA',
#  'JNL-IND-NEP-NPL',
#  'JNL-NPL-BEE-NPL',
#  'JNL-NPL-NEP-NPL',
#  'JOB-COD-LGM-COD',
#  'JRR-NGA-FUB-NGA',
#  'JUH-NGA-BAU-NGA',
#  'JUH-NGA-FUV-NGA',
#  'JUH-NGA-JAR-NGA',
#  'JUK-NGA-HAU-NGA',
#  'JUK-NGA-JBU-NGA',
#  'JUM-SDN-DIP-SDN',
#  'JUN-IND-ORI-IND',
#  'JUO-NGA-FUB-NGA',
#  'KAC-CHN-LIS-MMR',
#  'KAI-NGA-BOL-NGA',
#  'KAV-BRA-CBS-BRA',
#  'KAV-BRA-POR-BRA',
#  'KAZ-MNG-XAL-MNG',
#  'KBL-TCD-KNC-NER',
#  'KBO-SDN-KEO-COD',
#  'KBO-SDN-KEO-SDN',
#  'KBO-SDN-LOG-COD',
#  'KBR-ETH-GMO-ETH',
#  'KBY-NER-TTQ-NER',
#  'KCQ-NGA-FUV-NGA',
#  'KCQ-NGA-JUH-NGA',
#  'KCX-ETH-GMO-ETH',
#  'KDC-TZA-RUI-TZA',
#  'KDC-TZA-ZAJ-TZA',
#  'KDN-ZMB-LEH-ZMB',
#  'KDQ-BGD-SDR-BGD',
#  'KDT-KHM-KXM-THA',
#  'KDT-KHM-TTS-THA',
#  'KDV-MMR-MYA-MMR',
#  'KDX-NGA-FUB-NGA',
#  'KEO-SDN-BFA-SDN',
#  'KEO-SDN-MUH-SDN',
#  'KEP-IND-DCC-IND',
#  'KEQ-IND-HLB-IND',
#  'KEX-IND-BHB-IND',
#  'KEZ-NGA-IZI-NGA',
#  'KFA-IND-KFI-IND',
#  'KFC-IND-GBJ-IND',
#  'KFC-IND-GRT-IND',
#  'KFC-IND-ORT-IND',
#  'KFE-IND-KFI-IND',
#  'KFF-IND-GNO-IND',
#  'KFF-IND-MAR-IND',
#  'KFF-IND-ORI-IND',
#  'KFG-IND-YEA-IND',
#  'KFI-IND-KAN-IND',
#  'KFI-IND-TEL-IND',
#  'KFK-IND-LBJ-IND',
#  'KFP-IND-KRU-IND',
#  'KFQ-IND-NOE-IND',
#  'KFS-IND-DGO-IND',
#  'KFT-IND-RWR-IND',
#  'KFW-IND-HIN-IND',
#  'KFW-IND-SAT-IND',
#  'KFY-IND-GBM-IND',
#  'KFY-IND-NEP-NPL',
#  'KGH-PHL-BLW-PHL',
#  'KGH-PHL-BNC-PHL',
#  'KGH-PHL-KML-PHL',
#  'KGJ-NPL-NEP-NPL',
#  'KGK-ARG-NHD-PRY',
#  'KGK-ARG-POR-BRA',
#  'KGK-ARG-SPA-ARG',
#  'KGK-BRA-SPA-PRY',
#  'KGP-BRA-XET-BRA',
#  'KGY-CHN-BOD-NPL',
#  'KGY-NPL-BOD-NPL',
#  'KGY-NPL-NEP-NPL',
#  'KHA-IND-BEN-IND',
#  'KHJ-NGA-IKL-NGA',
#  'KHN-IND-BHB-IND',
#  'KHN-IND-BHI-IND',
#  'KHN-IND-NOE-IND',
#  'KHR-IND-ORI-IND',
#  'KHT-IND-MXJ-IND',
#  'KHU-AGO-UMB-AGO',
#  'KIF-NPL-NEP-NPL',
#  'KIN-COD-RUN-BDI',
#  'KIP-NPL-NEP-NPL',
#  'KIP-NPL-THL-NPL',
#  'KIX-IND-NNP-IND',
#  'KIX-IND-PZN-MMR',
#  'KJB-GTM-CNM-GTM',
#  'KJL-NPL-NEP-NPL',
#  'KJP-THA-PWO-MMR',
#  'KKH-MMR-LIS-MMR',
#  'KKR-NGA-BAU-NGA',
#  'KKR-NGA-JAR-NGA',
#  'KKR-NGA-LDD-NGA',
#  'KKS-NGA-FUV-NGA',
#  'KKT-NPL-NEP-NPL',
#  'KKW-COG-NZU-COG',
#  'KLA-USA-ENG-USA',
#  'KLH-PNG-BBV-PNG',
#  'KMD-PHL-KGH-PHL',
#  'KMM-IND-NMF-IND',
#  'KMR-IRQ-HAC-IRQ',
#  'KMR-TUR-AII-TUR',
#  'KMV-BRA-CAR-BRA',
#  'KNA-NGA-FUB-NGA',
#  'KNG-COD-KMB-AGO',
#  'KNJ-GTM-CNM-GTM',
#  'KNJ-MEX-MTZ-MEX',
#  'KNN-IND-BHB-IND',
#  'KNN-IND-GOM-IND',
#  'KNQ-MYS-KNS-MYS',
#  'KNS-MYS-MEO-MYS',
#  'KNS-MYS-MFA-THA',
#  'KNS-MYS-SOU-THA',
#  'KNU-GIN-DAF-CIV',
#  'KNU-GIN-DAF-GIN',
#  'KOE-SDN-ANU-ETH',
#  'KOE-SDN-MUR-SDN',
#  'KOW-NGA-FUB-NGA',
#  'KOW-NGA-YEN-NGA',
#  'KPA-NGA-FUV-NGA',
#  'KPK-NGA-JBU-NGA',
#  'KPP-MMR-BWE-MMR',
#  'KPP-MMR-KSW-MMR',
#  'KPP-MMR-KVU-MMR',
#  'KPP-MMR-KVY-MMR',
#  'KQR-MYS-BDR-MYS',
#  'KQR-MYS-DRG-MYS',
#  'KQR-MYS-DTP-MYS',
#  'KQR-MYS-TSG-MYS',
#  'KQT-MYS-BSY-MYS',
#  'KQT-MYS-TIH-MYS',
#  'KQV-MYS-MVV-MYS',
#  'KQY-ETH-GMO-ETH',
#  'KRU-IND-ORI-IND',
#  'KRU-IND-SAT-IND',
#  'KRU-IND-SDR-BGD',
#  'KRW-CIV-DAF-CIV',
#  'KRW-LBR-DAF-CIV',
#  'KSC-PHL-BNC-PHL',
#  'KSF-CMR-BAZ-CMR',
#  'KSK-USA-ENG-USA',
#  'KSM-NGA-DOH-NGA',
#  'KSM-NGA-FUB-NGA',
#  'KSO-NGA-FUB-NGA',
#  'KSQ-NGA-FUV-NGA',
#  'KSW-THA-PWO-MMR',
#  'KTB-ETH-GMO-ETH',
#  'KTE-NPL-BOD-NPL',
#  'KTR-MYS-BDR-MYS',
#  'KTR-MYS-DTP-MYS',
#  'KTR-MYS-KQR-MYS',
#  'KTR-MYS-KZS-MYS',
#  'KUB-NGA-JBU-NGA',
#  'KUH-NGA-PIY-NGA',
#  'KUM-RUS-CHE-RUS',
#  'KUM-RUS-LEZ-RUS',
#  'KUR-TKM-TUK-TKM',
#  'KVL-MMR-MYA-MMR',
#  'KVQ-MMR-SHN-MMR',
#  'KVU-MMR-BWE-MMR',
#  'KVU-MMR-KVY-MMR',
#  'KVY-MMR-KSW-MMR',
#  'KWN-AGO-NBA-AGO',
#  'KWY-AGO-KMB-AGO',
#  'KWY-AGO-KNG-AGO',
#  'KWY-AGO-KNG-COD',
#  'KWY-AGO-YOM-AGO',
#  'KWY-AGO-YOM-COD',
#  'KWY-COD-KMB-AGO',
#  'KXD-MYS-DPP-MYS',
#  'KXD-MYS-MVV-MYS',
#  'KXH-ETH-TUV-ETH',
#  'KXI-MYS-BNB-MYS',
#  'KXI-MYS-PLZ-MYS',
#  'KXK-MMR-BLK-MMR',
#  'KXK-MMR-PDU-MMR',
#  'KXT-PNG-SIC-PNG',
#  'KXU-IND-ORI-IND',
#  'KXU-IND-TEL-IND',
#  'KXV-IND-ORI-IND',
#  'KXV-IND-SRB-IND',
#  'KXV-IND-TEL-IND',
#  'KYB-PHL-BNC-PHL',
#  'KYB-PHL-KGH-PHL',
#  'KYI-MYS-NRM-MYS',
#  'KYL-USA-ENG-USA',
#  'KYV-NPL-DHI-NPL',
#  'KYV-NPL-MAI-NPL',
#  'KYV-NPL-MGP-NPL',
#  'KYV-NPL-RJS-NPL',
#  'KYV-NPL-SAT-NPL',
#  'KYV-NPL-SMM-NPL',
#  'KYV-NPL-THQ-NPL',
#  'KYY-PNG-GAJ-PNG',
#  'KZH-SDN-APD-SDN',
#  'KZH-SDN-FIA-SDN',
#  'KZJ-MYS-DTP-MYS',
#  'KZL-IDN-MHS-IDN',
#  'KZQ-NPL-NEP-NPL',
#  'KZS-MYS-DTP-MYS',
#  'KZS-MYS-TXA-MYS',
#  'KZT-MYS-DTP-MYS',
#  'KZX-IDN-TLW-IDN',
#  'LAE-IND-CDJ-IND',
#  'LAE-IND-GBK-IND',
#  'LAK-NGA-FUB-NGA',
#  'LAV-LVA-BEL-BLR',
#  'LAV-LVA-LIT-LTU',
#  'LAV-LVA-RUS-RUS',
#  'LAY-MMR-DUU-CHN',
#  'LAY-MMR-NRR-MMR',
#  'LBA-MMR-KKH-MMR',
#  'LBA-MMR-LHU-MMR',
#  'LBA-MMR-PRK-MMR',
#  'LBF-CHN-LBJ-IND',
#  'LBF-IND-LBJ-IND',
#  'LBU-PNG-BUK-PNG',
#  'LBU-PNG-YLU-PNG',
#  'LCH-AGO-NBA-AGO',
#  'LCH-ZMB-LUE-ZMB',
#  'LDH-NGA-FUB-NGA',
#  'LEG-PRY-AYO-PRY',
#  'LEG-PRY-SPA-PRY',
#  'LEG-PRY-TMF-PRY',
#  'LEH-ZMB-TOI-ZMB',
#  'LEM-CMR-BAZ-CMR',
#  'LEN-HND-SPA-HND',
#  'LEN-SLV-SPA-SLV',
#  'LEP-BTN-NEP-BTN',
#  'LEP-IND-NEP-BTN',
#  'LEP-IND-NEP-IND',
#  'LEP-NPL-NEP-NPL',
#  'LEY-IDN-TLZ-IDN',
#  'LFA-CMR-BAZ-CMR',
#  'LGN-ETH-XOM-SDN',
#  'LHM-CHN-BOD-NPL',
#  'LHM-IND-LIF-IND',
#  'LHM-IND-XSR-IND',
#  'LHM-NPL-BOD-NPL',
#  'LHP-BTN-NEP-BTN',
#  'LIF-IND-NEP-IND',
#  'LIF-IND-NEP-NPL',
#  'LIF-NPL-MGP-NPL',
#  'LIF-NPL-MRD-NPL',
#  'LIF-NPL-NEP-NPL',
#  'LII-NPL-LIF-NPL',
#  'LII-NPL-NEP-NPL',
#  'LIJ-ITA-EML-ITA',
#  'LIS-CHN-NBF-CHN',
#  'LIS-MMR-AHK-MMR',
#  'LIS-MMR-CMN-CHN',
#  'LIS-MMR-LHU-MMR',
#  'LIS-MMR-NOD-THA',
#  'LIV-LVA-LAV-LVA',
#  'LKE-UGA-NUJ-UGA',
#  'LKY-SDN-BFA-SDN',
#  'LKY-SDN-LOT-SDN',
#  'LLA-NGA-FUB-NGA',
#  'LMK-IND-PCK-MMR',
#  'LMK-IND-ZOM-IND',
#  'LMM-KHM-BRB-KHM',
#  'LMN-IND-KAN-IND',
#  'LMN-IND-MAR-IND',
#  'LND-MYS-MVV-MYS',
#  'LNH-MYS-JHI-MYS',
#  'LNH-MYS-MEO-MYS',
#  'LNH-MYS-SEA-MYS',
#  'LNH-MYS-TEA-MYS',
#  'LNH-MYS-ZLM-MYS',
#  'LNO-SDN-ACH-UGA',
#  'LNO-SDN-DID-SDN',
#  'LNO-SDN-KDJ-UGA',
#  'LNO-SDN-LOT-SDN',
#  'LOH-SDN-DID-SDN',
#  'LOH-SDN-LOT-SDN',
#  'LOH-SDN-TOQ-SDN',
#  'LOT-SDN-ACH-UGA',
#  'LOX-IDN-LCS-IDN',
#  'LOX-IDN-WEO-IDN',
#  'LPX-SDN-LOT-SDN',
#  'LRR-NPL-RAA-NPL',
#  'LSI-CHN-LIS-MMR',
#  'LSI-MMR-LIS-MMR',
#  'LSI-MMR-RAW-MMR',
#  'LTU-IDN-KZX-IDN',
#  'LTU-IDN-TLW-IDN',
#  'LUC-UGA-BFA-SDN',
#  'LUF-PNG-DGZ-PNG',
#  'LUF-PNG-ZGR-PNG',
#  'LUK-BTN-BOD-BTN',
#  'LUL-SDN-ACH-SDN',
#  'LUL-SDN-BFA-SDN',
#  'LUL-SDN-LKY-SDN',
#  'LUL-SDN-LOT-SDN',
#  'LUL-SDN-MHI-SDN',
#  'LUS-MMR-CNK-BGD',
#  'LUS-MMR-CNK-MMR',
#  'LUS-MMR-RMZ-BGD',
#  'LUS-MMR-USI-BGD',
#  'LWO-SDN-BXB-SDN',
#  'LWO-SDN-DIK-SDN',
#  'LYA-BTN-BOD-BTN',
#  'LYN-AGO-KHU-AGO',
#  'LYN-AGO-UMB-AGO',
#  'LYN-ZMB-LUE-ZMB',
#  'MAD-IDN-PEA-IDN',
#  'MAG-IND-BHO-IND',
#  'MAI-IND-BHO-IND',
#  'MAI-NPL-BHO-IND',
#  'MAI-NPL-NEP-NPL',
#  'MAL-IND-ULL-IND',
#  'MCA-PRY-SPA-PRY',
#  'MCK-AGO-NBA-AGO',
#  'MCK-ZMB-LUN-AGO',
#  'MCP-CMR-FAN-CMR',
#  'MCV-PNG-MGX-PNG',
#  'MDY-ETH-GMO-ETH',
#  'MEG-NCL-AJI-NCL',
#  'MEG-NCL-ANE-NCL',
#  'MEG-NCL-CIR-NCL',
#  'MES-TCD-DJC-TCD',
#  'MES-TCD-MNE-TCD',
#  'MES-TCD-MUB-TCD',
#  'MES-TCD-SHU-TCD',
#  'MEV-GIN-DAF-CIV',
#  'MEV-LBR-DAF-CIV',
#  'MEV-LBR-DAF-LBR',
#  'MFN-NGA-IZI-NGA',
#  'MFP-IDN-BUG-IDN',
#  'MFX-ETH-GMO-ETH',
#  'MGC-SDN-BEX-SDN',
#  'MGC-SDN-MGD-SDN',
#  'MGD-SDN-BFA-SDN',
#  'MGP-IND-NEP-IND',
#  'MGP-NPL-NEP-NPL',
#  'MGX-PNG-KLQ-PNG',
#  'MGX-PNG-KXZ-PNG',
#  'MGX-PNG-MEB-PNG',
#  'MHA-IND-ORI-IND',
#  'MHC-MEX-MTZ-GTM',
#  'MHI-SDN-ACH-UGA',
#  'MHI-SDN-BFA-SDN',
#  'MHI-UGA-BFA-SDN',
#  'MHJ-AFG-PRS-AFG',
#  ...]

# %%
ethno.loc[ethno.ID==m[:7]]
# Out:
#            ID ID_ISO_A3 ID_ISO_A2 ID_FIPS NAM_LABEL NAME_PROP NAME2 NAM_ANSI     CNT       C1  POP  LMP_POP1  \
# 5007  ZUA-NGA   zua-NGA    zua-ng  zua-NI      Zeem      Zeem  ZEEM     Zeem  Africa  Nigeria  400     400.0
#
#                                                     G LMP_CLASS    FAMILYPROP        FAMILY   LMP_C1 LANG_ISO EGIDS  \
# 5007  Afro-Asiatic, Chadic, West, B, B.3, Zaar Proper         L  Afro-Asiatic  AFRO-ASIATIC  Nigeria      zua     7
#
#                                                geometry
# 5007  MULTIPOLYGON (((9.39765 10.08233, 9.38924 10.0...

# %%
ethno.loc[ethno.ID==m[8:]]
# Out:
# Empty GeoDataFrame
# Columns: [ID, ID_ISO_A3, ID_ISO_A2, ID_FIPS, NAM_LABEL, NAME_PROP, NAME2, NAM_ANSI, CNT, C1, POP, LMP_POP1, G, LMP_CLASS, FAMILYPROP, FAMILY, LMP_C1, LANG_ISO, EGIDS, geometry]
# Index: []

# %%
missing_lang = []
for m in missing:
    a = ethno.loc[ethno.ID==m[:7]]
    b = ethno.loc[ethno.ID==m[8:]]
    if a.shape[0]==0:
        missing_lang.append(m[:7])
    if b.shape[0]==0:
        missing_lang.append(m[8:])
missing_lang = list(set(missing_lang))
missing_lang
# Out:
# ['MBF-SGP',
#  'LDD-NGA',
#  'ORN-MYS',
#  'DWL-MLI',
#  'BDJ-SDN',
#  'SCA-MMR',
#  'KPP-MMR',
#  'MGX-PNG',
#  'TVE-IDN',
#  'OMG-BRA',
#  'PNE-BRN',
#  'DAF-CIV',
#  'DEU-AUT',
#  'NAE-IDN',
#  'KZS-MYS',
#  'BNB-MYS',
#  'KLA-USA',
#  'RWR-NPL',
#  'TNI-IDN',
#  'FGR-TCD',
#  'TZB-MEX',
#  'MVJ-MEX',
#  'DTR-MYS',
#  'PEQ-USA',
#  'STC-SLB',
#  'TZZ-MEX',
#  'CCQ-MMR',
#  'DKS-SDN',
#  'WIW-AUS',
#  'HTI-IDN',
#  'SAP-PRY',
#  'NZU-COG',
#  'CKF-GTM',
#  'BFY-NPL',
#  'TZU-MEX',
#  'SER-USA',
#  'QUI-USA',
#  'HPO-MMR',
#  'OMG-PER',
#  'COD-BRA',
#  'BDH-SDN',
#  'BNC-PHL',
#  'DRW-AFG',
#  'CKK-GTM',
#  'KZH-EGY',
#  'MWD-AUS',
#  'KUR-TKM',
#  'NDO-AGO',
#  'VLR-VUT',
#  'MEG-NCL',
#  'MES-TCD',
#  'BDG-MYS',
#  'MTZ-GTM',
#  'BOD-BTN',
#  'MTZ-MEX',
#  'LMM-KHM',
#  'TEX-SDN',
#  'BZI-THA',
#  'GAV-PNG',
#  'PNV-AUS',
#  'YEN-NGA',
#  'SRK-MYS',
#  'NHF-AUS',
#  'MNQ-MYS',
#  'ORI-IND',
#  'PCK-MMR',
#  'PKN-AUS',
#  'TSK-NPL',
#  'BLM-SDN',
#  'TSK-BTN',
#  'IXI-GTM',
#  'SUM-NIC',
#  'TFR-CRI',
#  'CRQ-BOL',
#  'RIL-MMR',
#  'DID-SDN',
#  'NNX-CMR',
#  'AFB-YEM',
#  'WBA-GUY',
#  'KZH-SDN',
#  'TZT-GTM',
#  'ASB-USA',
#  'ANU-SDN',
#  'KGH-PHL',
#  'IZI-NGA',
#  'LBU-PNG',
#  'FER-SDN',
#  'NJU-AUS',
#  'BWI-BRA',
#  'MSZ-PNG',
#  'BDR-MYS',
#  'MGC-SDN',
#  'LAY-MMR',
#  'XMJ-TCD',
#  'LBA-MMR',
#  'JAI-MEX',
#  'CKJ-GTM',
#  'THU-SDN',
#  'LNO-SDN',
#  'PLP-NPL',
#  'YBD-MMR',
#  'SWN-LBY',
#  'TXX-MYS',
#  'KQR-MYS',
#  'PPV-BRA',
#  'ATU-SDN',
#  'AVU-SDN',
#  'ZMI-MYS',
#  'ATW-USA',
#  'KTR-MYS',
#  'JAK-MYS',
#  'BOA-BRA',
#  'SGL-AFG',
#  'KXK-MMR',
#  'EML-ITA',
#  'TNF-AFG',
#  'LYN-AGO',
#  'MUH-SDN',
#  'RAF-NPL',
#  'WUX-AUS',
#  'JBU-NGA',
#  'KSK-USA',
#  'LPX-SDN',
#  'DMG-MYS',
#  'KWY-AGO',
#  'COG-KHM',
#  'TIE-SDN',
#  'ACC-GTM',
#  'SPA-PRY',
#  'RUU-MYS',
#  'CCM-MYS',
#  'KZJ-MYS',
#  'NXU-IDN',
#  'SUL-PHL',
#  'GDH-AUS',
#  'HAC-IRQ',
#  'BBP-SDN',
#  'CKD-GTM',
#  'DZO-NPL',
#  'GBN-SDN',
#  'NIL-IDN',
#  'MGD-SDN',
#  'GBC-AUS',
#  'TDH-IND',
#  'LOT-SDN',
#  'SIH-NCL',
#  'NLN-MEX',
#  'POB-GTM',
#  'CKI-GTM',
#  'COA-MYS',
#  'LAV-LVA',
#  'MHT-BRA',
#  'BSY-MYS',
#  'TGB-MYS',
#  'ZLM-SGP',
#  'GNH-NGA',
#  'MYA-BGD',
#  'MFP-IDN',
#  'PAQ-AFG',
#  'AGP-PHL',
#  'SUQ-SDN',
#  'HVA-MEX',
#  'SHK-SDN',
#  'GRM-MYS',
#  'GZA-ETH',
#  'RAL-MMR',
#  'HUK-IDN',
#  'ORS-SGP',
#  'DSN-IDN',
#  'TDU-MYS',
#  'BAZ-CMR',
#  'KYV-NPL',
#  'NBF-CHN',
#  'IDR-SDN',
#  'KZX-IDN',
#  'XIA-CHN',
#  'NUS-SDN',
#  'KXI-MYS',
#  'GRK-TUR',
#  'KAV-BRA',
#  'PUB-MMR',
#  'DRD-NPL',
#  'LEN-SLV',
#  'FUV-NGA',
#  'SGL-TJK',
#  'LOX-IDN',
#  'NRR-MMR',
#  'MYT-PHL',
#  'BIS-NCL',
#  'BYM-AUS',
#  'ZRO-ECU',
#  'DPP-MYS',
#  'XBX-BRA',
#  'KOE-SDN',
#  'DAF-GIN',
#  'FRL-ITA',
#  'QUU-GTM',
#  'SPJ-TUR',
#  'ILW-IDN',
#  'WIT-USA',
#  'LKY-SDN',
#  'YET-PNG',
#  'SIC-PNG',
#  'BEN-NPL',
#  'TZE-MEX',
#  'NSQ-USA',
#  'AYX-CHN',
#  'BOH-COD',
#  'MHI-SDN',
#  'PEG-IND',
#  'PPR-IDN',
#  'DAP-IND',
#  'AII-TUR',
#  'CKW-GTM',
#  'ASB-CAN',
#  'NRM-MYS',
#  'ULL-IND',
#  'TOB-BOL',
#  'TID-MYS',
#  'JAS-NCL',
#  'MJU-IND',
#  'NEP-BTN',
#  'LOH-SDN',
#  'LII-NPL',
#  'POT-CAN',
#  'QUT-GTM',
#  'UDU-ETH',
#  'CBM-GTM',
#  'TZS-MEX',
#  'XET-BRA',
#  'IBI-NGA',
#  'CNM-GTM',
#  'GIO-CHN',
#  'DAF-LBR',
#  'MRO-IND',
#  'NUN-MMR',
#  'MKD-GRC',
#  'NFG-NGA',
#  'DIK-SDN',
#  'EMG-NPL',
#  'SPI-IDN',
#  'CKC-GTM',
#  'YWR-AUS',
#  'ORS-MYS',
#  'BJD-AUS',
#  'ACH-SDN',
#  'TUV-ETH',
#  'CSA-MEX',
#  'ELL-EGY',
#  'BXB-SDN',
#  'KZL-IDN',
#  'DMV-MYS',
#  'TOQ-SDN',
#  'PAP-ANT',
#  'DDD-SDN',
#  'SMM-NPL',
#  'IXJ-GTM',
#  'PYN-BRA',
#  'LOW-MYS',
#  'JAR-NGA',
#  'QXI-GTM',
#  'HRA-MMR',
#  'VIL-ARG',
#  'WGW-PNG',
#  'GNQ-MYS',
#  'JAI-GTM',
#  'FUB-NGA',
#  'VIC-ANT',
#  'BDZ-PAK',
#  'KBO-SDN',
#  'JNL-NPL',
#  'ZNE-SDN',
#  'ESI-USA',
#  'SUM-HND',
#  'TLW-IDN',
#  'PHV-AFG',
#  'CSZ-USA',
#  'CTI-MEX',
#  'KZT-MYS',
#  'TXA-MYS',
#  'SWW-VUT',
#  'MNI-MMR',
#  'EBO-COD',
#  'TMW-MYS',
#  'AJA-SDN',
#  'DKL-MLI',
#  'NEP-NPL',
#  'MYR-PER',
#  'DEC-SDN',
#  'AAL-NGA',
#  'CKA-MMR',
#  'TGG-PNG',
#  'DIB-SDN',
#  'PCR-CHN',
#  'MVV-MYS',
#  'HRV-ITA',
#  'BVI-SDN',
#  'XRE-BRA',
#  'DIP-SDN',
#  'LUL-SDN',
#  'HIN-NPL',
#  'TIH-MYS',
#  'PEA-IDN',
#  'CUN-GTM',
#  'WOA-AUS',
#  'VEC-BRA',
#  'MVJ-GTM',
#  'LEN-HND',
#  'VED-LKA',
#  'NEP-IND',
#  'CAR-BRA',
#  'COD-COL',
#  'NFK-NGA',
#  'IAP-BRA',
#  'KAZ-MNG',
#  'MVC-GTM',
#  'CDN-NPL',
#  'SRW-IDN',
#  'SEJ-PNG',
#  'ABF-MYS',
#  'POA-GTM',
#  'BJQ-MDG',
#  'KYY-PNG',
#  'MUR-SDN',
#  'LWO-SDN',
#  'PCJ-IND',
#  'HSF-MEX',
#  'DIW-SDN',
#  'BKB-PHL',
#  'DTB-MYS',
#  'KNS-MYS',
#  'TZC-MEX',
#  'LEG-PRY',
#  'ZAJ-TZA',
#  'CKE-GTM',
#  'CCJ-GNB',
#  'EST-EST',
#  'SMJ-IRN',
#  'APL-USA',
#  'LUF-PNG',
#  'CNM-MEX',
#  'TAE-COL',
#  'CAH-PER',
#  'POM-USA',
#  'BHK-PHL',
#  'BFA-SDN',
#  'LNH-MYS',
#  'BEX-SDN',
#  'DKR-MYS',
#  'BGX-TUR',
#  'ZAZ-NGA',
#  'ASM-BGD',
#  'TEH-ARG',
#  'SEE-CAN',
#  'GVP-BRA',
#  'IME-MRT',
#  'GMO-ETH',
#  'KGK-ARG',
#  'SXM-KHM',
#  'YUU-RUS',
#  'NJL-SDN',
#  'SBR-MYS',
#  'POU-GTM',
#  'YMA-NPL',
#  'NWM-SDN',
#  'BOT-SDN',
#  'KDV-MMR',
#  'MST-PHL',
#  'TLZ-IDN',
#  'KEO-SDN',
#  'SEA-MYS',
#  'DYN-AUS',
#  'PMW-USA',
#  'MHJ-AFG',
#  'KYL-USA',
#  'DRH-MNG',
#  'MMS-GTM',
#  'QUJ-GTM',
#  'JAH-MYS']

# %% [markdown]
# Lots of languages disappeared from v17 that may have been there in v16 they seem to be extinct.
#
# Let's find which languages in the replication file are not in v17 (let's also compare v16 vs v17 directly)

# %%
ethno.shape
# Out:
# (7387, 20)

# %%
ethno16 = gp.read_file(pathethno.replace('v17', 'v16') + 'langa.shp')
ethno16.head()
# Out:
#         ID ID_ISO_A3 ID_ISO_A2 ID_FIPS         NAM_LABEL          NAME_PROP              NAME2           NAM_ANSI       CNT  \
# 0  RUS-RUS   rus-RUS    rus-ru  rus-RS           Russian            Russian            RUSSIAN            Russian    Europe
# 1  ENG-USA   eng-USA    eng-us  eng-US           English            English            ENGLISH            English  Americas
# 2  POR-BRA   por-BRA    por-br  por-BR        Portuguese         Portuguese         PORTUGUESE         Portuguese  Americas
# 3  ENG-AUS   eng-AUS    eng-au  eng-AS           English            English            ENGLISH            English   Pacific
# 4  CMN-CHN   cmn-CHN    cmn-cn  cmn-CH  Mandarin Chinese  Chinese, Mandarin  CHINESE, MANDARIN  Chinese, Mandarin      Asia
#
#                    C1                                              POP   LMP_POP1                                                  G  \
# 0  Russian Federation  116,000,000 in Russian Federation (2002 census)  116000000                        Indo-European, Slavic, East
# 1       United States       215,000,000 in United States (2000 census)  215000000             Indo-European, Germanic, West, English
# 2              Brazil                     163,000,000 in Brazil (1998)  163000000  Indo-European, Italic, Romance, Italo-Western,...
# 3           Australia                   17,400,000 in Australia (2006)   17400000             Indo-European, Germanic, West, English
# 4               China               840,000,000 in China (2000 census)  840000000                              Sino-Tibetan, Chinese
#
#   LMP_CLASS     FAMILYPROP         FAMILY              LMP_C1 LANG_ISO                                           geometry
# 0         L  Indo-European  INDO-EUROPEAN  Russian Federation      rus  MULTIPOLYGON (((45.11381 43.19151, 45.06952 43...
# 1         L  Indo-European  INDO-EUROPEAN       United States      eng  MULTIPOLYGON (((-75.11965 19.97388, -75.11741 ...
# 2         L  Indo-European  INDO-EUROPEAN              Brazil      por  MULTIPOLYGON (((-52.13058 -31.97901, -52.12447...
# 3         L  Indo-European  INDO-EUROPEAN           Australia      eng  MULTIPOLYGON (((147.36099 -43.08758, 147.36375...
# 4         L   Sino-Tibetan   SINO-TIBETAN               China      cmn  MULTIPOLYGON (((108.65391 19.06045, 108.63222 ...

# %%
ethno_ID = set(ethno.ID)
ethno16_ID = set(ethno16.ID)

# %%
new_langs = len(ethno_ID.difference(ethno16_ID))
new_langs
# Out:
# 414

# %%
lost_langs = len(ethno16_ID.difference(ethno_ID))
lost_langs
# Out:
# 537

# %%
new_langs + lost_langs
# Out:
# 951

# %%
len(missing_lang)
# Out:
# 379

# %%
set(missing_lang).difference(ethno16_ID.difference(ethno_ID))
# Out:
# set()

# %%
ethno.loc[(ethno.ID==missing[0][:7])|(ethno.ID==missing[0][8:])].plot()
# Out:
# <AxesSubplot:>

# %%
ethno16.loc[(ethno16.ID==missing[0][:7])|(ethno16.ID==missing[0][8:])].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# So all missing languages are due to difference between v16 and 17
#
# We have (essencially) replicated his data

# %% [markdown]
# # New Data - Buffers

# %%
buffers= borders_geo[['identifier', 'border']].merge(merge_iden[['identifier']])
buffers
# Out:
#             identifier                                             border
# 0      KHK-MNG-CMN-CHN  LINESTRING (96.29691 42.52898, 96.30858 42.544...
# 1      KHG-CHN-CMN-CHN  LINESTRING (102.24263 29.72548, 102.20450 29.7...
# 2      ADX-CHN-CMN-CHN  MULTILINESTRING ((103.34328 32.41462, 103.3294...
# 3      XAL-CHN-CMN-CHN  MULTILINESTRING ((101.03075 36.42174, 101.0269...
# 4      KAZ-CHN-CMN-CHN  MULTILINESTRING ((85.79039 43.12162, 85.78670 ...
# ...                ...                                                ...
# 13820  MUC-CMR-BOE-CMR  LINESTRING (10.27755 6.54777, 10.27743 6.54410...
# 13821  TQL-VUT-URR-VUT  LINESTRING (167.36785 -13.52711, 167.36645 -13...
# 13822  BDX-IDN-TOY-IDN  LINESTRING (119.31693 -2.07812, 119.30790 -2.0...
# 13823  TUC-PNG-BBV-PNG  LINESTRING (147.83801 -5.67779, 147.83871 -5.6...
# 13824  AFN-NGA-NKX-NGA  MULTILINESTRING ((7.46682 4.54613, 7.46701 4.5...
#
# [13825 rows x 2 columns]

# %%
buffers.to_file(pathout + 'Dickens_ethnologue_bordersv17.json', driver="GeoJSON")

# %% [markdown]
# We convert to CEA to construct the buffers and create the data

# %%
buffers = buffers.to_crs(cea)

# %%
buffers.to_file(pathout + 'Dickens_ethnologue_bordersv17_cyl.json', driver="GeoJSON")

# %%
buffers = gp.read_file(pathout + 'Dickens_ethnologue_bordersv17_cyl.json', driver="GeoJSON")

# %%
buffers = dask_geopandas.from_geopandas(buffers, npartitions=10)

# %%
buffers.geometry = buffers.geometry.buffer(50000)
buffers = buffers.compute()
# Out:
# /users/ozak/micromamba/envs/GeoPython39env/lib/python3.9/site-packages/distributed/client.py:3125: UserWarning: Sending large graph of size 17.45 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(

# %%
buffers.to_file(pathout + 'Dickens_ethnologue_buffersv17_cyl.json', driver="GeoJSON")

# %%
buffers = buffers.to_crs(wgs84)

# %%
buffers.to_file(pathout + 'Dickens_ethnologue_buffersv17.json', driver="GeoJSON")

# %%
buffers.centroid.plot()
# Out:
# /tmp/ipykernel_3341423/2640991670.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   buffers.centroid.plot()
# <AxesSubplot:>

# %%
type(buffers)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# # New Data - Spatial Stats for New Buffers

# %%
buffers = gp.read_file(pathout + 'Dickens_ethnologue_buffersv17.json', driver="GeoJSON")
buffers.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
buffers.loc[buffers.is_valid==False]
# Out:
#             identifier                                           geometry
# 104    KLD-AUS-ENG-AUS                                               None
# 183    MYI-IND-HIN-IND                                               None
# 184    MUP-IND-HIN-IND                                               None
# 581    BGC-IND-HIN-IND                                               None
# 582    BHO-IND-HIN-IND                                               None
# 583    HOJ-IND-HIN-IND                                               None
# 585    BRA-IND-HIN-IND                                               None
# 587    SCK-IND-HIN-IND                                               None
# 1278   BJJ-IND-HIN-IND                                               None
# 1279   GNO-IND-HIN-IND                                               None
# 1282   BHA-IND-HIN-IND                                               None
# 1283   KWX-IND-HIN-IND                                               None
# 1335   VAH-IND-MAR-IND                                               None
# 1566   OJW-CAN-ENG-CAN  MULTIPOLYGON (((-104.90856 51.28984, -104.9154...
# 1986   TKB-IND-HIN-IND                                               None
# 1989   BFZ-IND-HIN-IND                                               None
# 2057   SAZ-IND-TAM-IND                                               None
# 2058   YEU-IND-TEL-IND                                               None
# 2791   AGI-IND-HIN-IND                                               None
# 3599   UNR-IND-HIN-IND                                               None
# 3682   ANR-IND-MAR-IND                                               None
# 4301   JNS-IND-HIN-IND                                               None
# 5040   KTD-AUS-ENG-AUS                                               None
# 5077   BIY-IND-HIN-IND                                               None
# 5150   STO-CAN-ENG-CAN  MULTIPOLYGON (((-115.73734 51.18978, -115.7373...
# 5817   DUB-IND-GUJ-IND                                               None
# 6550   REI-IND-TEL-IND                                               None
# 7163   BZX-MLI-FFM-MLI                                               None
# 7911   CAF-CAN-ENG-CAN  MULTIPOLYGON (((-122.77860 53.56444, -122.7376...
# 7914   THT-CAN-ENG-CAN  POLYGON ((-131.62634 57.64488, -131.64767 57.6...
# 7956   NKF-IND-MNI-IND                                               None
# 8709   VIS-IND-MAL-IND                                               None
# 12169  AAF-IND-MAL-IND                                               None
# 12827  KDR-LTU-LIT-LTU                                               None

# %%
buffers = buffers.loc[buffers.geometry!=None].reset_index(drop=True)

# %% [markdown]
# Work with CSI data to compute spatial statistics

# %%
CSI = os.listdir(proot + 'CSI')

# %%
CSI.remove('ReadMe.txt')
CSI.sort()
CSI
# Out:
# ['dif2AverageCalories.tif',
#  'dif2AverageCalories0.tif',
#  'dif2AverageCaloriesNo0.tif',
#  'dif2OptCalories.tif',
#  'dif2OptCalories0.tif',
#  'dif2OptCaloriesNo0.tif',
#  'difAverageCalories.tif',
#  'difAverageCalories0.tif',
#  'difAverageCaloriesNo0.tif',
#  'difOptCalories.tif',
#  'difOptCalories0.tif',
#  'difOptCaloriesNo0.tif',
#  'post1500AverageCalories.tif',
#  'post1500AverageCalories0.tif',
#  'post1500AverageCaloriesNo0.tif',
#  'post1500OptCalories.tif',
#  'post1500OptCalories0.tif',
#  'post1500OptCaloriesNo0.tif',
#  'pre15002AverageCalories.tif',
#  'pre15002AverageCalories0.tif',
#  'pre15002AverageCaloriesNo0.tif',
#  'pre15002OptCalories.tif',
#  'pre15002OptCalories0.tif',
#  'pre15002OptCaloriesNo0.tif',
#  'pre1500AverageCalories.tif',
#  'pre1500AverageCalories0.tif',
#  'pre1500AverageCaloriesNo0.tif',
#  'pre1500OptCalories.tif',
#  'pre1500OptCalories0.tif',
#  'pre1500OptCaloriesNo0.tif']

# %%
# %%time
for r in CSI:
    print(r.replace('.tif', ''))
    # Import raster
    csi = gr.from_file(proot + '/CSI/' + r)
    # Compute stats for first section of buffer
    out= csi.stats(buffers, add_stats={'median':np.ma.median, 'std':np.ma.std, 'max':np.ma.max, 'min':np.ma.min}, raster_out=False)
    print(out.columns)
    for c in out.columns[1:]:
        out[c] = out[c].astype(float)
    out.columns = ['identifier'] + [r.replace('.tif', '') + c for c in out.columns[1:]]
    out.to_stata(pathstats + 'Dickens_ethnologue_v17_' + r.replace('.tif', '') + '.dta', version=117, write_index=False)
# Out:
# dif2AverageCalories
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# dif2AverageCalories0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# dif2AverageCaloriesNo0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# dif2OptCalories
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# dif2OptCalories0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# dif2OptCaloriesNo0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# difAverageCalories
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# difAverageCalories0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# difAverageCaloriesNo0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# difOptCalories
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# difOptCalories0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# difOptCaloriesNo0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# post1500AverageCalories
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# post1500AverageCalories0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# post1500AverageCaloriesNo0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# post1500OptCalories
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# post1500OptCalories0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# post1500OptCaloriesNo0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre15002AverageCalories
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre15002AverageCalories0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre15002AverageCaloriesNo0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre15002OptCalories
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre15002OptCalories0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre15002OptCaloriesNo0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre1500AverageCalories
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre1500AverageCalories0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre1500AverageCaloriesNo0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre1500OptCalories
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre1500OptCalories0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# pre1500OptCaloriesNo0
# Index(['identifier', 'min', 'mean', 'median', 'max', 'std'], dtype='object')
# CPU times: user 16min 50s, sys: 6min 46s, total: 23min 36s
# Wall time: 21min 2s

# %%
# %%time
out = []
for r in CSI:
    print(r.replace('.tif', ''))
    out1 = pd.read_stata(pathstats + 'Dickens_ethnologue_v17_' + r.replace('.tif', '') + '.dta')   
    out1 = out1.set_index(['identifier'])
    out.append(out1)
# Out:
# dif2AverageCalories
# dif2AverageCalories0
# dif2AverageCaloriesNo0
# dif2OptCalories
# dif2OptCalories0
# dif2OptCaloriesNo0
# difAverageCalories
# difAverageCalories0
# difAverageCaloriesNo0
# difOptCalories
# difOptCalories0
# difOptCaloriesNo0
# post1500AverageCalories
# post1500AverageCalories0
# post1500AverageCaloriesNo0
# post1500OptCalories
# post1500OptCalories0
# post1500OptCaloriesNo0
# pre15002AverageCalories
# pre15002AverageCalories0
# pre15002AverageCaloriesNo0
# pre15002OptCalories
# pre15002OptCalories0
# pre15002OptCaloriesNo0
# pre1500AverageCalories
# pre1500AverageCalories0
# pre1500AverageCaloriesNo0
# pre1500OptCalories
# pre1500OptCalories0
# pre1500OptCaloriesNo0
# CPU times: user 1.54 s, sys: 380 ms, total: 1.92 s
# Wall time: 1.83 s

# %%
out = pd.concat(out, axis=1)

# %%
out.to_stata(proot + 'Dickens_OrBuf_v17_stats.dta', version=117)
